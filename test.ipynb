# %%
from src.biohack.utils import (
    load_tiffs,
    matrix_to_image,
    load_image_paths,
    load_grayscale_image,
)
import numpy as np
import pandas as pd
from PIL import Image
from pathlib import Path
from IPython.display import display
from sklearn.cluster import DBSCAN

# %%
paths = load_image_paths(r"data/separated_frames/")
len(paths)
# Out:
# 800

# %%
from dataclasses import dataclass

@dataclass
class ImageSample:
    path: Path
    original_image: np.ndarray
    blacked_image: np.ndarray

# %%
filtered_imgs = []

import time
from src.biohack.utils import set_lowest_percent_to_black

from IPython.display import clear_output

for i in range(len(paths)):
# for i in range(len(paths))[:1]:
    img_test = load_grayscale_image(paths[i])
    print(f"Image {i}, shape: {paths[i].name}")
    # matrix_to_image(img_test, show=True)

    img_blackened = set_lowest_percent_to_black(img_test, black_percent=99.5)
    # matrix_to_image(img_blackened, show=False)
    filtered_imgs.append(ImageSample(paths[i], img_test, img_blackened))
    # time.sleep(.2)
    # clear_output(wait=True)
# Out:
# Image 0, shape: ch20_URA7_URA8_001-crop2_frame_0.tiff
# Image 1, shape: ch20_URA7_URA8_001-crop2_frame_1.tiff
# Image 2, shape: ch20_URA7_URA8_001-crop2_frame_10.tiff
# Image 3, shape: ch20_URA7_URA8_001-crop2_frame_11.tiff
# Image 4, shape: ch20_URA7_URA8_001-crop2_frame_12.tiff
# Image 5, shape: ch20_URA7_URA8_001-crop2_frame_13.tiff
# Image 6, shape: ch20_URA7_URA8_001-crop2_frame_14.tiff
# Image 7, shape: ch20_URA7_URA8_001-crop2_frame_15.tiff
# Image 8, shape: ch20_URA7_URA8_001-crop2_frame_16.tiff
# Image 9, shape: ch20_URA7_URA8_001-crop2_frame_17.tiff
# Image 10, shape: ch20_URA7_URA8_001-crop2_frame_18.tiff
# Image 11, shape: ch20_URA7_URA8_001-crop2_frame_19.tiff
# Image 12, shape: ch20_URA7_URA8_001-crop2_frame_2.tiff
# Image 13, shape: ch20_URA7_URA8_001-crop2_frame_20.tiff
# Image 14, shape: ch20_URA7_URA8_001-crop2_frame_21.tiff
# Image 15, shape: ch20_URA7_URA8_001-crop2_frame_22.tiff
# Image 16, shape: ch20_URA7_URA8_001-crop2_frame_23.tiff
# Image 17, shape: ch20_URA7_URA8_001-crop2_frame_24.tiff
# Image 18, shape: ch20_URA7_URA8_001-crop2_frame_25.tiff
# Image 19, shape: ch20_URA7_URA8_001-crop2_frame_26.tiff
# Image 20, shape: ch20_URA7_URA8_001-crop2_frame_27.tiff
# Image 21, shape: ch20_URA7_URA8_001-crop2_frame_28.tiff
# Image 22, shape: ch20_URA7_URA8_001-crop2_frame_29.tiff
# Image 23, shape: ch20_URA7_URA8_001-crop2_frame_3.tiff
# Image 24, shape: ch20_URA7_URA8_001-crop2_frame_30.tiff
# Image 25, shape: ch20_URA7_URA8_001-crop2_frame_31.tiff
# Image 26, shape: ch20_URA7_URA8_001-crop2_frame_32.tiff
# Image 27, shape: ch20_URA7_URA8_001-crop2_frame_33.tiff
# Image 28, shape: ch20_URA7_URA8_001-crop2_frame_34.tiff
# Image 29, shape: ch20_URA7_URA8_001-crop2_frame_35.tiff
# Image 30, shape: ch20_URA7_URA8_001-crop2_frame_36.tiff
# Image 31, shape: ch20_URA7_URA8_001-crop2_frame_37.tiff
# Image 32, shape: ch20_URA7_URA8_001-crop2_frame_38.tiff
# Image 33, shape: ch20_URA7_URA8_001-crop2_frame_39.tiff
# Image 34, shape: ch20_URA7_URA8_001-crop2_frame_4.tiff
# Image 35, shape: ch20_URA7_URA8_001-crop2_frame_40.tiff
# Image 36, shape: ch20_URA7_URA8_001-crop2_frame_41.tiff
# Image 37, shape: ch20_URA7_URA8_001-crop2_frame_42.tiff
# Image 38, shape: ch20_URA7_URA8_001-crop2_frame_43.tiff
# Image 39, shape: ch20_URA7_URA8_001-crop2_frame_44.tiff
# Image 40, shape: ch20_URA7_URA8_001-crop2_frame_45.tiff
# Image 41, shape: ch20_URA7_URA8_001-crop2_frame_46.tiff
# Image 42, shape: ch20_URA7_URA8_001-crop2_frame_47.tiff
# Image 43, shape: ch20_URA7_URA8_001-crop2_frame_48.tiff
# Image 44, shape: ch20_URA7_URA8_001-crop2_frame_49.tiff
# Image 45, shape: ch20_URA7_URA8_001-crop2_frame_5.tiff
# Image 46, shape: ch20_URA7_URA8_001-crop2_frame_50.tiff
# Image 47, shape: ch20_URA7_URA8_001-crop2_frame_51.tiff
# Image 48, shape: ch20_URA7_URA8_001-crop2_frame_52.tiff
# Image 49, shape: ch20_URA7_URA8_001-crop2_frame_53.tiff
# Image 50, shape: ch20_URA7_URA8_001-crop2_frame_54.tiff
# Image 51, shape: ch20_URA7_URA8_001-crop2_frame_55.tiff
# Image 52, shape: ch20_URA7_URA8_001-crop2_frame_56.tiff
# Image 53, shape: ch20_URA7_URA8_001-crop2_frame_57.tiff
# Image 54, shape: ch20_URA7_URA8_001-crop2_frame_58.tiff
# Image 55, shape: ch20_URA7_URA8_001-crop2_frame_59.tiff
# Image 56, shape: ch20_URA7_URA8_001-crop2_frame_6.tiff
# Image 57, shape: ch20_URA7_URA8_001-crop2_frame_60.tiff
# Image 58, shape: ch20_URA7_URA8_001-crop2_frame_61.tiff
# Image 59, shape: ch20_URA7_URA8_001-crop2_frame_62.tiff
# Image 60, shape: ch20_URA7_URA8_001-crop2_frame_63.tiff
# Image 61, shape: ch20_URA7_URA8_001-crop2_frame_64.tiff
# Image 62, shape: ch20_URA7_URA8_001-crop2_frame_65.tiff
# Image 63, shape: ch20_URA7_URA8_001-crop2_frame_66.tiff
# Image 64, shape: ch20_URA7_URA8_001-crop2_frame_67.tiff
# Image 65, shape: ch20_URA7_URA8_001-crop2_frame_68.tiff
# Image 66, shape: ch20_URA7_URA8_001-crop2_frame_69.tiff
# Image 67, shape: ch20_URA7_URA8_001-crop2_frame_7.tiff
# Image 68, shape: ch20_URA7_URA8_001-crop2_frame_70.tiff
# Image 69, shape: ch20_URA7_URA8_001-crop2_frame_71.tiff
# Image 70, shape: ch20_URA7_URA8_001-crop2_frame_72.tiff
# Image 71, shape: ch20_URA7_URA8_001-crop2_frame_73.tiff
# Image 72, shape: ch20_URA7_URA8_001-crop2_frame_74.tiff
# Image 73, shape: ch20_URA7_URA8_001-crop2_frame_75.tiff
# Image 74, shape: ch20_URA7_URA8_001-crop2_frame_76.tiff
# Image 75, shape: ch20_URA7_URA8_001-crop2_frame_77.tiff
# Image 76, shape: ch20_URA7_URA8_001-crop2_frame_78.tiff
# Image 77, shape: ch20_URA7_URA8_001-crop2_frame_79.tiff
# Image 78, shape: ch20_URA7_URA8_001-crop2_frame_8.tiff
# Image 79, shape: ch20_URA7_URA8_001-crop2_frame_80.tiff
# Image 80, shape: ch20_URA7_URA8_001-crop2_frame_81.tiff
# Image 81, shape: ch20_URA7_URA8_001-crop2_frame_82.tiff
# Image 82, shape: ch20_URA7_URA8_001-crop2_frame_83.tiff
# Image 83, shape: ch20_URA7_URA8_001-crop2_frame_84.tiff
# Image 84, shape: ch20_URA7_URA8_001-crop2_frame_85.tiff
# Image 85, shape: ch20_URA7_URA8_001-crop2_frame_86.tiff
# Image 86, shape: ch20_URA7_URA8_001-crop2_frame_87.tiff
# Image 87, shape: ch20_URA7_URA8_001-crop2_frame_88.tiff
# Image 88, shape: ch20_URA7_URA8_001-crop2_frame_89.tiff
# Image 89, shape: ch20_URA7_URA8_001-crop2_frame_9.tiff
# Image 90, shape: ch20_URA7_URA8_001-crop2_frame_90.tiff
# Image 91, shape: ch20_URA7_URA8_001-crop2_frame_91.tiff
# Image 92, shape: ch20_URA7_URA8_001-crop2_frame_92.tiff
# Image 93, shape: ch20_URA7_URA8_001-crop2_frame_93.tiff
# Image 94, shape: ch20_URA7_URA8_001-crop2_frame_94.tiff
# Image 95, shape: ch20_URA7_URA8_001-crop2_frame_95.tiff
# Image 96, shape: ch20_URA7_URA8_001-crop2_frame_96.tiff
# Image 97, shape: ch20_URA7_URA8_001-crop2_frame_97.tiff
# Image 98, shape: ch20_URA7_URA8_001-crop2_frame_98.tiff
# Image 99, shape: ch20_URA7_URA8_001-crop2_frame_99.tiff
# Image 100, shape: ch20_URA7_URA8_001-crop3_frame_0.tiff
# Image 101, shape: ch20_URA7_URA8_001-crop3_frame_1.tiff
# Image 102, shape: ch20_URA7_URA8_001-crop3_frame_10.tiff
# Image 103, shape: ch20_URA7_URA8_001-crop3_frame_11.tiff
# Image 104, shape: ch20_URA7_URA8_001-crop3_frame_12.tiff
# Image 105, shape: ch20_URA7_URA8_001-crop3_frame_13.tiff
# Image 106, shape: ch20_URA7_URA8_001-crop3_frame_14.tiff
# Image 107, shape: ch20_URA7_URA8_001-crop3_frame_15.tiff
# Image 108, shape: ch20_URA7_URA8_001-crop3_frame_16.tiff
# Image 109, shape: ch20_URA7_URA8_001-crop3_frame_17.tiff
# Image 110, shape: ch20_URA7_URA8_001-crop3_frame_18.tiff
# Image 111, shape: ch20_URA7_URA8_001-crop3_frame_19.tiff
# Image 112, shape: ch20_URA7_URA8_001-crop3_frame_2.tiff
# Image 113, shape: ch20_URA7_URA8_001-crop3_frame_20.tiff
# Image 114, shape: ch20_URA7_URA8_001-crop3_frame_21.tiff
# Image 115, shape: ch20_URA7_URA8_001-crop3_frame_22.tiff
# Image 116, shape: ch20_URA7_URA8_001-crop3_frame_23.tiff
# Image 117, shape: ch20_URA7_URA8_001-crop3_frame_24.tiff
# Image 118, shape: ch20_URA7_URA8_001-crop3_frame_25.tiff
# Image 119, shape: ch20_URA7_URA8_001-crop3_frame_26.tiff
# Image 120, shape: ch20_URA7_URA8_001-crop3_frame_27.tiff
# Image 121, shape: ch20_URA7_URA8_001-crop3_frame_28.tiff
# Image 122, shape: ch20_URA7_URA8_001-crop3_frame_29.tiff
# Image 123, shape: ch20_URA7_URA8_001-crop3_frame_3.tiff
# Image 124, shape: ch20_URA7_URA8_001-crop3_frame_30.tiff
# Image 125, shape: ch20_URA7_URA8_001-crop3_frame_31.tiff
# Image 126, shape: ch20_URA7_URA8_001-crop3_frame_32.tiff
# Image 127, shape: ch20_URA7_URA8_001-crop3_frame_33.tiff
# Image 128, shape: ch20_URA7_URA8_001-crop3_frame_34.tiff
# Image 129, shape: ch20_URA7_URA8_001-crop3_frame_35.tiff
# Image 130, shape: ch20_URA7_URA8_001-crop3_frame_36.tiff
# Image 131, shape: ch20_URA7_URA8_001-crop3_frame_37.tiff
# Image 132, shape: ch20_URA7_URA8_001-crop3_frame_38.tiff
# Image 133, shape: ch20_URA7_URA8_001-crop3_frame_39.tiff
# Image 134, shape: ch20_URA7_URA8_001-crop3_frame_4.tiff
# Image 135, shape: ch20_URA7_URA8_001-crop3_frame_40.tiff
# Image 136, shape: ch20_URA7_URA8_001-crop3_frame_41.tiff
# Image 137, shape: ch20_URA7_URA8_001-crop3_frame_42.tiff
# Image 138, shape: ch20_URA7_URA8_001-crop3_frame_43.tiff
# Image 139, shape: ch20_URA7_URA8_001-crop3_frame_44.tiff
# Image 140, shape: ch20_URA7_URA8_001-crop3_frame_45.tiff
# Image 141, shape: ch20_URA7_URA8_001-crop3_frame_46.tiff
# Image 142, shape: ch20_URA7_URA8_001-crop3_frame_47.tiff
# Image 143, shape: ch20_URA7_URA8_001-crop3_frame_48.tiff
# Image 144, shape: ch20_URA7_URA8_001-crop3_frame_49.tiff
# Image 145, shape: ch20_URA7_URA8_001-crop3_frame_5.tiff
# Image 146, shape: ch20_URA7_URA8_001-crop3_frame_50.tiff
# Image 147, shape: ch20_URA7_URA8_001-crop3_frame_51.tiff
# Image 148, shape: ch20_URA7_URA8_001-crop3_frame_52.tiff
# Image 149, shape: ch20_URA7_URA8_001-crop3_frame_53.tiff
# Image 150, shape: ch20_URA7_URA8_001-crop3_frame_54.tiff
# Image 151, shape: ch20_URA7_URA8_001-crop3_frame_55.tiff
# Image 152, shape: ch20_URA7_URA8_001-crop3_frame_56.tiff
# Image 153, shape: ch20_URA7_URA8_001-crop3_frame_57.tiff
# Image 154, shape: ch20_URA7_URA8_001-crop3_frame_58.tiff
# Image 155, shape: ch20_URA7_URA8_001-crop3_frame_59.tiff
# Image 156, shape: ch20_URA7_URA8_001-crop3_frame_6.tiff
# Image 157, shape: ch20_URA7_URA8_001-crop3_frame_60.tiff
# Image 158, shape: ch20_URA7_URA8_001-crop3_frame_61.tiff
# Image 159, shape: ch20_URA7_URA8_001-crop3_frame_62.tiff
# Image 160, shape: ch20_URA7_URA8_001-crop3_frame_63.tiff
# Image 161, shape: ch20_URA7_URA8_001-crop3_frame_64.tiff
# Image 162, shape: ch20_URA7_URA8_001-crop3_frame_65.tiff
# Image 163, shape: ch20_URA7_URA8_001-crop3_frame_66.tiff
# Image 164, shape: ch20_URA7_URA8_001-crop3_frame_67.tiff
# Image 165, shape: ch20_URA7_URA8_001-crop3_frame_68.tiff
# Image 166, shape: ch20_URA7_URA8_001-crop3_frame_69.tiff
# Image 167, shape: ch20_URA7_URA8_001-crop3_frame_7.tiff
# Image 168, shape: ch20_URA7_URA8_001-crop3_frame_70.tiff
# Image 169, shape: ch20_URA7_URA8_001-crop3_frame_71.tiff
# Image 170, shape: ch20_URA7_URA8_001-crop3_frame_72.tiff
# Image 171, shape: ch20_URA7_URA8_001-crop3_frame_73.tiff
# Image 172, shape: ch20_URA7_URA8_001-crop3_frame_74.tiff
# Image 173, shape: ch20_URA7_URA8_001-crop3_frame_75.tiff
# Image 174, shape: ch20_URA7_URA8_001-crop3_frame_76.tiff
# Image 175, shape: ch20_URA7_URA8_001-crop3_frame_77.tiff
# Image 176, shape: ch20_URA7_URA8_001-crop3_frame_78.tiff
# Image 177, shape: ch20_URA7_URA8_001-crop3_frame_79.tiff
# Image 178, shape: ch20_URA7_URA8_001-crop3_frame_8.tiff
# Image 179, shape: ch20_URA7_URA8_001-crop3_frame_80.tiff
# Image 180, shape: ch20_URA7_URA8_001-crop3_frame_81.tiff
# Image 181, shape: ch20_URA7_URA8_001-crop3_frame_82.tiff
# Image 182, shape: ch20_URA7_URA8_001-crop3_frame_83.tiff
# Image 183, shape: ch20_URA7_URA8_001-crop3_frame_84.tiff
# Image 184, shape: ch20_URA7_URA8_001-crop3_frame_85.tiff
# Image 185, shape: ch20_URA7_URA8_001-crop3_frame_86.tiff
# Image 186, shape: ch20_URA7_URA8_001-crop3_frame_87.tiff
# Image 187, shape: ch20_URA7_URA8_001-crop3_frame_88.tiff
# Image 188, shape: ch20_URA7_URA8_001-crop3_frame_89.tiff
# Image 189, shape: ch20_URA7_URA8_001-crop3_frame_9.tiff
# Image 190, shape: ch20_URA7_URA8_001-crop3_frame_90.tiff
# Image 191, shape: ch20_URA7_URA8_001-crop3_frame_91.tiff
# Image 192, shape: ch20_URA7_URA8_001-crop3_frame_92.tiff
# Image 193, shape: ch20_URA7_URA8_001-crop3_frame_93.tiff
# Image 194, shape: ch20_URA7_URA8_001-crop3_frame_94.tiff
# Image 195, shape: ch20_URA7_URA8_001-crop3_frame_95.tiff
# Image 196, shape: ch20_URA7_URA8_001-crop3_frame_96.tiff
# Image 197, shape: ch20_URA7_URA8_001-crop3_frame_97.tiff
# Image 198, shape: ch20_URA7_URA8_001-crop3_frame_98.tiff
# Image 199, shape: ch20_URA7_URA8_001-crop3_frame_99.tiff
# Image 200, shape: ch20_URA7_URA8_002-crop1_frame_0.tiff
# Image 201, shape: ch20_URA7_URA8_002-crop1_frame_1.tiff
# Image 202, shape: ch20_URA7_URA8_002-crop1_frame_10.tiff
# Image 203, shape: ch20_URA7_URA8_002-crop1_frame_11.tiff
# Image 204, shape: ch20_URA7_URA8_002-crop1_frame_12.tiff
# Image 205, shape: ch20_URA7_URA8_002-crop1_frame_13.tiff
# Image 206, shape: ch20_URA7_URA8_002-crop1_frame_14.tiff
# Image 207, shape: ch20_URA7_URA8_002-crop1_frame_15.tiff
# Image 208, shape: ch20_URA7_URA8_002-crop1_frame_16.tiff
# Image 209, shape: ch20_URA7_URA8_002-crop1_frame_17.tiff
# Image 210, shape: ch20_URA7_URA8_002-crop1_frame_18.tiff
# Image 211, shape: ch20_URA7_URA8_002-crop1_frame_19.tiff
# Image 212, shape: ch20_URA7_URA8_002-crop1_frame_2.tiff
# Image 213, shape: ch20_URA7_URA8_002-crop1_frame_20.tiff
# Image 214, shape: ch20_URA7_URA8_002-crop1_frame_21.tiff
# Image 215, shape: ch20_URA7_URA8_002-crop1_frame_22.tiff
# Image 216, shape: ch20_URA7_URA8_002-crop1_frame_23.tiff
# Image 217, shape: ch20_URA7_URA8_002-crop1_frame_24.tiff
# Image 218, shape: ch20_URA7_URA8_002-crop1_frame_25.tiff
# Image 219, shape: ch20_URA7_URA8_002-crop1_frame_26.tiff
# Image 220, shape: ch20_URA7_URA8_002-crop1_frame_27.tiff
# Image 221, shape: ch20_URA7_URA8_002-crop1_frame_28.tiff
# Image 222, shape: ch20_URA7_URA8_002-crop1_frame_29.tiff
# Image 223, shape: ch20_URA7_URA8_002-crop1_frame_3.tiff
# Image 224, shape: ch20_URA7_URA8_002-crop1_frame_30.tiff
# Image 225, shape: ch20_URA7_URA8_002-crop1_frame_31.tiff
# Image 226, shape: ch20_URA7_URA8_002-crop1_frame_32.tiff
# Image 227, shape: ch20_URA7_URA8_002-crop1_frame_33.tiff
# Image 228, shape: ch20_URA7_URA8_002-crop1_frame_34.tiff
# Image 229, shape: ch20_URA7_URA8_002-crop1_frame_35.tiff
# Image 230, shape: ch20_URA7_URA8_002-crop1_frame_36.tiff
# Image 231, shape: ch20_URA7_URA8_002-crop1_frame_37.tiff
# Image 232, shape: ch20_URA7_URA8_002-crop1_frame_38.tiff
# Image 233, shape: ch20_URA7_URA8_002-crop1_frame_39.tiff
# Image 234, shape: ch20_URA7_URA8_002-crop1_frame_4.tiff
# Image 235, shape: ch20_URA7_URA8_002-crop1_frame_40.tiff
# Image 236, shape: ch20_URA7_URA8_002-crop1_frame_41.tiff
# Image 237, shape: ch20_URA7_URA8_002-crop1_frame_42.tiff
# Image 238, shape: ch20_URA7_URA8_002-crop1_frame_43.tiff
# Image 239, shape: ch20_URA7_URA8_002-crop1_frame_44.tiff
# Image 240, shape: ch20_URA7_URA8_002-crop1_frame_45.tiff
# Image 241, shape: ch20_URA7_URA8_002-crop1_frame_46.tiff
# Image 242, shape: ch20_URA7_URA8_002-crop1_frame_47.tiff
# Image 243, shape: ch20_URA7_URA8_002-crop1_frame_48.tiff
# Image 244, shape: ch20_URA7_URA8_002-crop1_frame_49.tiff
# Image 245, shape: ch20_URA7_URA8_002-crop1_frame_5.tiff
# Image 246, shape: ch20_URA7_URA8_002-crop1_frame_50.tiff
# Image 247, shape: ch20_URA7_URA8_002-crop1_frame_51.tiff
# Image 248, shape: ch20_URA7_URA8_002-crop1_frame_52.tiff
# Image 249, shape: ch20_URA7_URA8_002-crop1_frame_53.tiff
# Image 250, shape: ch20_URA7_URA8_002-crop1_frame_54.tiff
# Image 251, shape: ch20_URA7_URA8_002-crop1_frame_55.tiff
# Image 252, shape: ch20_URA7_URA8_002-crop1_frame_56.tiff
# Image 253, shape: ch20_URA7_URA8_002-crop1_frame_57.tiff
# Image 254, shape: ch20_URA7_URA8_002-crop1_frame_58.tiff
# Image 255, shape: ch20_URA7_URA8_002-crop1_frame_59.tiff
# Image 256, shape: ch20_URA7_URA8_002-crop1_frame_6.tiff
# Image 257, shape: ch20_URA7_URA8_002-crop1_frame_60.tiff
# Image 258, shape: ch20_URA7_URA8_002-crop1_frame_61.tiff
# Image 259, shape: ch20_URA7_URA8_002-crop1_frame_62.tiff
# Image 260, shape: ch20_URA7_URA8_002-crop1_frame_63.tiff
# Image 261, shape: ch20_URA7_URA8_002-crop1_frame_64.tiff
# Image 262, shape: ch20_URA7_URA8_002-crop1_frame_65.tiff
# Image 263, shape: ch20_URA7_URA8_002-crop1_frame_66.tiff
# Image 264, shape: ch20_URA7_URA8_002-crop1_frame_67.tiff
# Image 265, shape: ch20_URA7_URA8_002-crop1_frame_68.tiff
# Image 266, shape: ch20_URA7_URA8_002-crop1_frame_69.tiff
# Image 267, shape: ch20_URA7_URA8_002-crop1_frame_7.tiff
# Image 268, shape: ch20_URA7_URA8_002-crop1_frame_70.tiff
# Image 269, shape: ch20_URA7_URA8_002-crop1_frame_71.tiff
# Image 270, shape: ch20_URA7_URA8_002-crop1_frame_72.tiff
# Image 271, shape: ch20_URA7_URA8_002-crop1_frame_73.tiff
# Image 272, shape: ch20_URA7_URA8_002-crop1_frame_74.tiff
# Image 273, shape: ch20_URA7_URA8_002-crop1_frame_75.tiff
# Image 274, shape: ch20_URA7_URA8_002-crop1_frame_76.tiff
# Image 275, shape: ch20_URA7_URA8_002-crop1_frame_77.tiff
# Image 276, shape: ch20_URA7_URA8_002-crop1_frame_78.tiff
# Image 277, shape: ch20_URA7_URA8_002-crop1_frame_79.tiff
# Image 278, shape: ch20_URA7_URA8_002-crop1_frame_8.tiff
# Image 279, shape: ch20_URA7_URA8_002-crop1_frame_80.tiff
# Image 280, shape: ch20_URA7_URA8_002-crop1_frame_81.tiff
# Image 281, shape: ch20_URA7_URA8_002-crop1_frame_82.tiff
# Image 282, shape: ch20_URA7_URA8_002-crop1_frame_83.tiff
# Image 283, shape: ch20_URA7_URA8_002-crop1_frame_84.tiff
# Image 284, shape: ch20_URA7_URA8_002-crop1_frame_85.tiff
# Image 285, shape: ch20_URA7_URA8_002-crop1_frame_86.tiff
# Image 286, shape: ch20_URA7_URA8_002-crop1_frame_87.tiff
# Image 287, shape: ch20_URA7_URA8_002-crop1_frame_88.tiff
# Image 288, shape: ch20_URA7_URA8_002-crop1_frame_89.tiff
# Image 289, shape: ch20_URA7_URA8_002-crop1_frame_9.tiff
# Image 290, shape: ch20_URA7_URA8_002-crop1_frame_90.tiff
# Image 291, shape: ch20_URA7_URA8_002-crop1_frame_91.tiff
# Image 292, shape: ch20_URA7_URA8_002-crop1_frame_92.tiff
# Image 293, shape: ch20_URA7_URA8_002-crop1_frame_93.tiff
# Image 294, shape: ch20_URA7_URA8_002-crop1_frame_94.tiff
# Image 295, shape: ch20_URA7_URA8_002-crop1_frame_95.tiff
# Image 296, shape: ch20_URA7_URA8_002-crop1_frame_96.tiff
# Image 297, shape: ch20_URA7_URA8_002-crop1_frame_97.tiff
# Image 298, shape: ch20_URA7_URA8_002-crop1_frame_98.tiff
# Image 299, shape: ch20_URA7_URA8_002-crop1_frame_99.tiff
# Image 300, shape: ch20_URA7_URA8_002-crop2_frame_0.tiff
# Image 301, shape: ch20_URA7_URA8_002-crop2_frame_1.tiff
# Image 302, shape: ch20_URA7_URA8_002-crop2_frame_10.tiff
# Image 303, shape: ch20_URA7_URA8_002-crop2_frame_11.tiff
# Image 304, shape: ch20_URA7_URA8_002-crop2_frame_12.tiff
# Image 305, shape: ch20_URA7_URA8_002-crop2_frame_13.tiff
# Image 306, shape: ch20_URA7_URA8_002-crop2_frame_14.tiff
# Image 307, shape: ch20_URA7_URA8_002-crop2_frame_15.tiff
# Image 308, shape: ch20_URA7_URA8_002-crop2_frame_16.tiff
# Image 309, shape: ch20_URA7_URA8_002-crop2_frame_17.tiff
# Image 310, shape: ch20_URA7_URA8_002-crop2_frame_18.tiff
# Image 311, shape: ch20_URA7_URA8_002-crop2_frame_19.tiff
# Image 312, shape: ch20_URA7_URA8_002-crop2_frame_2.tiff
# Image 313, shape: ch20_URA7_URA8_002-crop2_frame_20.tiff
# Image 314, shape: ch20_URA7_URA8_002-crop2_frame_21.tiff
# Image 315, shape: ch20_URA7_URA8_002-crop2_frame_22.tiff
# Image 316, shape: ch20_URA7_URA8_002-crop2_frame_23.tiff
# Image 317, shape: ch20_URA7_URA8_002-crop2_frame_24.tiff
# Image 318, shape: ch20_URA7_URA8_002-crop2_frame_25.tiff
# Image 319, shape: ch20_URA7_URA8_002-crop2_frame_26.tiff
# Image 320, shape: ch20_URA7_URA8_002-crop2_frame_27.tiff
# Image 321, shape: ch20_URA7_URA8_002-crop2_frame_28.tiff
# Image 322, shape: ch20_URA7_URA8_002-crop2_frame_29.tiff
# Image 323, shape: ch20_URA7_URA8_002-crop2_frame_3.tiff
# Image 324, shape: ch20_URA7_URA8_002-crop2_frame_30.tiff
# Image 325, shape: ch20_URA7_URA8_002-crop2_frame_31.tiff
# Image 326, shape: ch20_URA7_URA8_002-crop2_frame_32.tiff
# Image 327, shape: ch20_URA7_URA8_002-crop2_frame_33.tiff
# Image 328, shape: ch20_URA7_URA8_002-crop2_frame_34.tiff
# Image 329, shape: ch20_URA7_URA8_002-crop2_frame_35.tiff
# Image 330, shape: ch20_URA7_URA8_002-crop2_frame_36.tiff
# Image 331, shape: ch20_URA7_URA8_002-crop2_frame_37.tiff
# Image 332, shape: ch20_URA7_URA8_002-crop2_frame_38.tiff
# Image 333, shape: ch20_URA7_URA8_002-crop2_frame_39.tiff
# Image 334, shape: ch20_URA7_URA8_002-crop2_frame_4.tiff
# Image 335, shape: ch20_URA7_URA8_002-crop2_frame_40.tiff
# Image 336, shape: ch20_URA7_URA8_002-crop2_frame_41.tiff
# Image 337, shape: ch20_URA7_URA8_002-crop2_frame_42.tiff
# Image 338, shape: ch20_URA7_URA8_002-crop2_frame_43.tiff
# Image 339, shape: ch20_URA7_URA8_002-crop2_frame_44.tiff
# Image 340, shape: ch20_URA7_URA8_002-crop2_frame_45.tiff
# Image 341, shape: ch20_URA7_URA8_002-crop2_frame_46.tiff
# Image 342, shape: ch20_URA7_URA8_002-crop2_frame_47.tiff
# Image 343, shape: ch20_URA7_URA8_002-crop2_frame_48.tiff
# Image 344, shape: ch20_URA7_URA8_002-crop2_frame_49.tiff
# Image 345, shape: ch20_URA7_URA8_002-crop2_frame_5.tiff
# Image 346, shape: ch20_URA7_URA8_002-crop2_frame_50.tiff
# Image 347, shape: ch20_URA7_URA8_002-crop2_frame_51.tiff
# Image 348, shape: ch20_URA7_URA8_002-crop2_frame_52.tiff
# Image 349, shape: ch20_URA7_URA8_002-crop2_frame_53.tiff
# Image 350, shape: ch20_URA7_URA8_002-crop2_frame_54.tiff
# Image 351, shape: ch20_URA7_URA8_002-crop2_frame_55.tiff
# Image 352, shape: ch20_URA7_URA8_002-crop2_frame_56.tiff
# Image 353, shape: ch20_URA7_URA8_002-crop2_frame_57.tiff
# Image 354, shape: ch20_URA7_URA8_002-crop2_frame_58.tiff
# Image 355, shape: ch20_URA7_URA8_002-crop2_frame_59.tiff
# Image 356, shape: ch20_URA7_URA8_002-crop2_frame_6.tiff
# Image 357, shape: ch20_URA7_URA8_002-crop2_frame_60.tiff
# Image 358, shape: ch20_URA7_URA8_002-crop2_frame_61.tiff
# Image 359, shape: ch20_URA7_URA8_002-crop2_frame_62.tiff
# Image 360, shape: ch20_URA7_URA8_002-crop2_frame_63.tiff
# Image 361, shape: ch20_URA7_URA8_002-crop2_frame_64.tiff
# Image 362, shape: ch20_URA7_URA8_002-crop2_frame_65.tiff
# Image 363, shape: ch20_URA7_URA8_002-crop2_frame_66.tiff
# Image 364, shape: ch20_URA7_URA8_002-crop2_frame_67.tiff
# Image 365, shape: ch20_URA7_URA8_002-crop2_frame_68.tiff
# Image 366, shape: ch20_URA7_URA8_002-crop2_frame_69.tiff
# Image 367, shape: ch20_URA7_URA8_002-crop2_frame_7.tiff
# Image 368, shape: ch20_URA7_URA8_002-crop2_frame_70.tiff
# Image 369, shape: ch20_URA7_URA8_002-crop2_frame_71.tiff
# Image 370, shape: ch20_URA7_URA8_002-crop2_frame_72.tiff
# Image 371, shape: ch20_URA7_URA8_002-crop2_frame_73.tiff
# Image 372, shape: ch20_URA7_URA8_002-crop2_frame_74.tiff
# Image 373, shape: ch20_URA7_URA8_002-crop2_frame_75.tiff
# Image 374, shape: ch20_URA7_URA8_002-crop2_frame_76.tiff
# Image 375, shape: ch20_URA7_URA8_002-crop2_frame_77.tiff
# Image 376, shape: ch20_URA7_URA8_002-crop2_frame_78.tiff
# Image 377, shape: ch20_URA7_URA8_002-crop2_frame_79.tiff
# Image 378, shape: ch20_URA7_URA8_002-crop2_frame_8.tiff
# Image 379, shape: ch20_URA7_URA8_002-crop2_frame_80.tiff
# Image 380, shape: ch20_URA7_URA8_002-crop2_frame_81.tiff
# Image 381, shape: ch20_URA7_URA8_002-crop2_frame_82.tiff
# Image 382, shape: ch20_URA7_URA8_002-crop2_frame_83.tiff
# Image 383, shape: ch20_URA7_URA8_002-crop2_frame_84.tiff
# Image 384, shape: ch20_URA7_URA8_002-crop2_frame_85.tiff
# Image 385, shape: ch20_URA7_URA8_002-crop2_frame_86.tiff
# Image 386, shape: ch20_URA7_URA8_002-crop2_frame_87.tiff
# Image 387, shape: ch20_URA7_URA8_002-crop2_frame_88.tiff
# Image 388, shape: ch20_URA7_URA8_002-crop2_frame_89.tiff
# Image 389, shape: ch20_URA7_URA8_002-crop2_frame_9.tiff
# Image 390, shape: ch20_URA7_URA8_002-crop2_frame_90.tiff
# Image 391, shape: ch20_URA7_URA8_002-crop2_frame_91.tiff
# Image 392, shape: ch20_URA7_URA8_002-crop2_frame_92.tiff
# Image 393, shape: ch20_URA7_URA8_002-crop2_frame_93.tiff
# Image 394, shape: ch20_URA7_URA8_002-crop2_frame_94.tiff
# Image 395, shape: ch20_URA7_URA8_002-crop2_frame_95.tiff
# Image 396, shape: ch20_URA7_URA8_002-crop2_frame_96.tiff
# Image 397, shape: ch20_URA7_URA8_002-crop2_frame_97.tiff
# Image 398, shape: ch20_URA7_URA8_002-crop2_frame_98.tiff
# Image 399, shape: ch20_URA7_URA8_002-crop2_frame_99.tiff
# Image 400, shape: ch20_URA7_URA8_002-crop3_frame_0.tiff
# Image 401, shape: ch20_URA7_URA8_002-crop3_frame_1.tiff
# Image 402, shape: ch20_URA7_URA8_002-crop3_frame_10.tiff
# Image 403, shape: ch20_URA7_URA8_002-crop3_frame_11.tiff
# Image 404, shape: ch20_URA7_URA8_002-crop3_frame_12.tiff
# Image 405, shape: ch20_URA7_URA8_002-crop3_frame_13.tiff
# Image 406, shape: ch20_URA7_URA8_002-crop3_frame_14.tiff
# Image 407, shape: ch20_URA7_URA8_002-crop3_frame_15.tiff
# Image 408, shape: ch20_URA7_URA8_002-crop3_frame_16.tiff
# Image 409, shape: ch20_URA7_URA8_002-crop3_frame_17.tiff
# Image 410, shape: ch20_URA7_URA8_002-crop3_frame_18.tiff
# Image 411, shape: ch20_URA7_URA8_002-crop3_frame_19.tiff
# Image 412, shape: ch20_URA7_URA8_002-crop3_frame_2.tiff
# Image 413, shape: ch20_URA7_URA8_002-crop3_frame_20.tiff
# Image 414, shape: ch20_URA7_URA8_002-crop3_frame_21.tiff
# Image 415, shape: ch20_URA7_URA8_002-crop3_frame_22.tiff
# Image 416, shape: ch20_URA7_URA8_002-crop3_frame_23.tiff
# Image 417, shape: ch20_URA7_URA8_002-crop3_frame_24.tiff
# Image 418, shape: ch20_URA7_URA8_002-crop3_frame_25.tiff
# Image 419, shape: ch20_URA7_URA8_002-crop3_frame_26.tiff
# Image 420, shape: ch20_URA7_URA8_002-crop3_frame_27.tiff
# Image 421, shape: ch20_URA7_URA8_002-crop3_frame_28.tiff
# Image 422, shape: ch20_URA7_URA8_002-crop3_frame_29.tiff
# Image 423, shape: ch20_URA7_URA8_002-crop3_frame_3.tiff
# Image 424, shape: ch20_URA7_URA8_002-crop3_frame_30.tiff
# Image 425, shape: ch20_URA7_URA8_002-crop3_frame_31.tiff
# Image 426, shape: ch20_URA7_URA8_002-crop3_frame_32.tiff
# Image 427, shape: ch20_URA7_URA8_002-crop3_frame_33.tiff
# Image 428, shape: ch20_URA7_URA8_002-crop3_frame_34.tiff
# Image 429, shape: ch20_URA7_URA8_002-crop3_frame_35.tiff
# Image 430, shape: ch20_URA7_URA8_002-crop3_frame_36.tiff
# Image 431, shape: ch20_URA7_URA8_002-crop3_frame_37.tiff
# Image 432, shape: ch20_URA7_URA8_002-crop3_frame_38.tiff
# Image 433, shape: ch20_URA7_URA8_002-crop3_frame_39.tiff
# Image 434, shape: ch20_URA7_URA8_002-crop3_frame_4.tiff
# Image 435, shape: ch20_URA7_URA8_002-crop3_frame_40.tiff
# Image 436, shape: ch20_URA7_URA8_002-crop3_frame_41.tiff
# Image 437, shape: ch20_URA7_URA8_002-crop3_frame_42.tiff
# Image 438, shape: ch20_URA7_URA8_002-crop3_frame_43.tiff
# Image 439, shape: ch20_URA7_URA8_002-crop3_frame_44.tiff
# Image 440, shape: ch20_URA7_URA8_002-crop3_frame_45.tiff
# Image 441, shape: ch20_URA7_URA8_002-crop3_frame_46.tiff
# Image 442, shape: ch20_URA7_URA8_002-crop3_frame_47.tiff
# Image 443, shape: ch20_URA7_URA8_002-crop3_frame_48.tiff
# Image 444, shape: ch20_URA7_URA8_002-crop3_frame_49.tiff
# Image 445, shape: ch20_URA7_URA8_002-crop3_frame_5.tiff
# Image 446, shape: ch20_URA7_URA8_002-crop3_frame_50.tiff
# Image 447, shape: ch20_URA7_URA8_002-crop3_frame_51.tiff
# Image 448, shape: ch20_URA7_URA8_002-crop3_frame_52.tiff
# Image 449, shape: ch20_URA7_URA8_002-crop3_frame_53.tiff
# Image 450, shape: ch20_URA7_URA8_002-crop3_frame_54.tiff
# Image 451, shape: ch20_URA7_URA8_002-crop3_frame_55.tiff
# Image 452, shape: ch20_URA7_URA8_002-crop3_frame_56.tiff
# Image 453, shape: ch20_URA7_URA8_002-crop3_frame_57.tiff
# Image 454, shape: ch20_URA7_URA8_002-crop3_frame_58.tiff
# Image 455, shape: ch20_URA7_URA8_002-crop3_frame_59.tiff
# Image 456, shape: ch20_URA7_URA8_002-crop3_frame_6.tiff
# Image 457, shape: ch20_URA7_URA8_002-crop3_frame_60.tiff
# Image 458, shape: ch20_URA7_URA8_002-crop3_frame_61.tiff
# Image 459, shape: ch20_URA7_URA8_002-crop3_frame_62.tiff
# Image 460, shape: ch20_URA7_URA8_002-crop3_frame_63.tiff
# Image 461, shape: ch20_URA7_URA8_002-crop3_frame_64.tiff
# Image 462, shape: ch20_URA7_URA8_002-crop3_frame_65.tiff
# Image 463, shape: ch20_URA7_URA8_002-crop3_frame_66.tiff
# Image 464, shape: ch20_URA7_URA8_002-crop3_frame_67.tiff
# Image 465, shape: ch20_URA7_URA8_002-crop3_frame_68.tiff
# Image 466, shape: ch20_URA7_URA8_002-crop3_frame_69.tiff
# Image 467, shape: ch20_URA7_URA8_002-crop3_frame_7.tiff
# Image 468, shape: ch20_URA7_URA8_002-crop3_frame_70.tiff
# Image 469, shape: ch20_URA7_URA8_002-crop3_frame_71.tiff
# Image 470, shape: ch20_URA7_URA8_002-crop3_frame_72.tiff
# Image 471, shape: ch20_URA7_URA8_002-crop3_frame_73.tiff
# Image 472, shape: ch20_URA7_URA8_002-crop3_frame_74.tiff
# Image 473, shape: ch20_URA7_URA8_002-crop3_frame_75.tiff
# Image 474, shape: ch20_URA7_URA8_002-crop3_frame_76.tiff
# Image 475, shape: ch20_URA7_URA8_002-crop3_frame_77.tiff
# Image 476, shape: ch20_URA7_URA8_002-crop3_frame_78.tiff
# Image 477, shape: ch20_URA7_URA8_002-crop3_frame_79.tiff
# Image 478, shape: ch20_URA7_URA8_002-crop3_frame_8.tiff
# Image 479, shape: ch20_URA7_URA8_002-crop3_frame_80.tiff
# Image 480, shape: ch20_URA7_URA8_002-crop3_frame_81.tiff
# Image 481, shape: ch20_URA7_URA8_002-crop3_frame_82.tiff
# Image 482, shape: ch20_URA7_URA8_002-crop3_frame_83.tiff
# Image 483, shape: ch20_URA7_URA8_002-crop3_frame_84.tiff
# Image 484, shape: ch20_URA7_URA8_002-crop3_frame_85.tiff
# Image 485, shape: ch20_URA7_URA8_002-crop3_frame_86.tiff
# Image 486, shape: ch20_URA7_URA8_002-crop3_frame_87.tiff
# Image 487, shape: ch20_URA7_URA8_002-crop3_frame_88.tiff
# Image 488, shape: ch20_URA7_URA8_002-crop3_frame_89.tiff
# Image 489, shape: ch20_URA7_URA8_002-crop3_frame_9.tiff
# Image 490, shape: ch20_URA7_URA8_002-crop3_frame_90.tiff
# Image 491, shape: ch20_URA7_URA8_002-crop3_frame_91.tiff
# Image 492, shape: ch20_URA7_URA8_002-crop3_frame_92.tiff
# Image 493, shape: ch20_URA7_URA8_002-crop3_frame_93.tiff
# Image 494, shape: ch20_URA7_URA8_002-crop3_frame_94.tiff
# Image 495, shape: ch20_URA7_URA8_002-crop3_frame_95.tiff
# Image 496, shape: ch20_URA7_URA8_002-crop3_frame_96.tiff
# Image 497, shape: ch20_URA7_URA8_002-crop3_frame_97.tiff
# Image 498, shape: ch20_URA7_URA8_002-crop3_frame_98.tiff
# Image 499, shape: ch20_URA7_URA8_002-crop3_frame_99.tiff
# Image 500, shape: ch20_URA7_URA8_002-crop4_frame_0.tiff
# Image 501, shape: ch20_URA7_URA8_002-crop4_frame_1.tiff
# Image 502, shape: ch20_URA7_URA8_002-crop4_frame_10.tiff
# Image 503, shape: ch20_URA7_URA8_002-crop4_frame_11.tiff
# Image 504, shape: ch20_URA7_URA8_002-crop4_frame_12.tiff
# Image 505, shape: ch20_URA7_URA8_002-crop4_frame_13.tiff
# Image 506, shape: ch20_URA7_URA8_002-crop4_frame_14.tiff
# Image 507, shape: ch20_URA7_URA8_002-crop4_frame_15.tiff
# Image 508, shape: ch20_URA7_URA8_002-crop4_frame_16.tiff
# Image 509, shape: ch20_URA7_URA8_002-crop4_frame_17.tiff
# Image 510, shape: ch20_URA7_URA8_002-crop4_frame_18.tiff
# Image 511, shape: ch20_URA7_URA8_002-crop4_frame_19.tiff
# Image 512, shape: ch20_URA7_URA8_002-crop4_frame_2.tiff
# Image 513, shape: ch20_URA7_URA8_002-crop4_frame_20.tiff
# Image 514, shape: ch20_URA7_URA8_002-crop4_frame_21.tiff
# Image 515, shape: ch20_URA7_URA8_002-crop4_frame_22.tiff
# Image 516, shape: ch20_URA7_URA8_002-crop4_frame_23.tiff
# Image 517, shape: ch20_URA7_URA8_002-crop4_frame_24.tiff
# Image 518, shape: ch20_URA7_URA8_002-crop4_frame_25.tiff
# Image 519, shape: ch20_URA7_URA8_002-crop4_frame_26.tiff
# Image 520, shape: ch20_URA7_URA8_002-crop4_frame_27.tiff
# Image 521, shape: ch20_URA7_URA8_002-crop4_frame_28.tiff
# Image 522, shape: ch20_URA7_URA8_002-crop4_frame_29.tiff
# Image 523, shape: ch20_URA7_URA8_002-crop4_frame_3.tiff
# Image 524, shape: ch20_URA7_URA8_002-crop4_frame_30.tiff
# Image 525, shape: ch20_URA7_URA8_002-crop4_frame_31.tiff
# Image 526, shape: ch20_URA7_URA8_002-crop4_frame_32.tiff
# Image 527, shape: ch20_URA7_URA8_002-crop4_frame_33.tiff
# Image 528, shape: ch20_URA7_URA8_002-crop4_frame_34.tiff
# Image 529, shape: ch20_URA7_URA8_002-crop4_frame_35.tiff
# Image 530, shape: ch20_URA7_URA8_002-crop4_frame_36.tiff
# Image 531, shape: ch20_URA7_URA8_002-crop4_frame_37.tiff
# Image 532, shape: ch20_URA7_URA8_002-crop4_frame_38.tiff
# Image 533, shape: ch20_URA7_URA8_002-crop4_frame_39.tiff
# Image 534, shape: ch20_URA7_URA8_002-crop4_frame_4.tiff
# Image 535, shape: ch20_URA7_URA8_002-crop4_frame_40.tiff
# Image 536, shape: ch20_URA7_URA8_002-crop4_frame_41.tiff
# Image 537, shape: ch20_URA7_URA8_002-crop4_frame_42.tiff
# Image 538, shape: ch20_URA7_URA8_002-crop4_frame_43.tiff
# Image 539, shape: ch20_URA7_URA8_002-crop4_frame_44.tiff
# Image 540, shape: ch20_URA7_URA8_002-crop4_frame_45.tiff
# Image 541, shape: ch20_URA7_URA8_002-crop4_frame_46.tiff
# Image 542, shape: ch20_URA7_URA8_002-crop4_frame_47.tiff
# Image 543, shape: ch20_URA7_URA8_002-crop4_frame_48.tiff
# Image 544, shape: ch20_URA7_URA8_002-crop4_frame_49.tiff
# Image 545, shape: ch20_URA7_URA8_002-crop4_frame_5.tiff
# Image 546, shape: ch20_URA7_URA8_002-crop4_frame_50.tiff
# Image 547, shape: ch20_URA7_URA8_002-crop4_frame_51.tiff
# Image 548, shape: ch20_URA7_URA8_002-crop4_frame_52.tiff
# Image 549, shape: ch20_URA7_URA8_002-crop4_frame_53.tiff
# Image 550, shape: ch20_URA7_URA8_002-crop4_frame_54.tiff
# Image 551, shape: ch20_URA7_URA8_002-crop4_frame_55.tiff
# Image 552, shape: ch20_URA7_URA8_002-crop4_frame_56.tiff
# Image 553, shape: ch20_URA7_URA8_002-crop4_frame_57.tiff
# Image 554, shape: ch20_URA7_URA8_002-crop4_frame_58.tiff
# Image 555, shape: ch20_URA7_URA8_002-crop4_frame_59.tiff
# Image 556, shape: ch20_URA7_URA8_002-crop4_frame_6.tiff
# Image 557, shape: ch20_URA7_URA8_002-crop4_frame_60.tiff
# Image 558, shape: ch20_URA7_URA8_002-crop4_frame_61.tiff
# Image 559, shape: ch20_URA7_URA8_002-crop4_frame_62.tiff
# Image 560, shape: ch20_URA7_URA8_002-crop4_frame_63.tiff
# Image 561, shape: ch20_URA7_URA8_002-crop4_frame_64.tiff
# Image 562, shape: ch20_URA7_URA8_002-crop4_frame_65.tiff
# Image 563, shape: ch20_URA7_URA8_002-crop4_frame_66.tiff
# Image 564, shape: ch20_URA7_URA8_002-crop4_frame_67.tiff
# Image 565, shape: ch20_URA7_URA8_002-crop4_frame_68.tiff
# Image 566, shape: ch20_URA7_URA8_002-crop4_frame_69.tiff
# Image 567, shape: ch20_URA7_URA8_002-crop4_frame_7.tiff
# Image 568, shape: ch20_URA7_URA8_002-crop4_frame_70.tiff
# Image 569, shape: ch20_URA7_URA8_002-crop4_frame_71.tiff
# Image 570, shape: ch20_URA7_URA8_002-crop4_frame_72.tiff
# Image 571, shape: ch20_URA7_URA8_002-crop4_frame_73.tiff
# Image 572, shape: ch20_URA7_URA8_002-crop4_frame_74.tiff
# Image 573, shape: ch20_URA7_URA8_002-crop4_frame_75.tiff
# Image 574, shape: ch20_URA7_URA8_002-crop4_frame_76.tiff
# Image 575, shape: ch20_URA7_URA8_002-crop4_frame_77.tiff
# Image 576, shape: ch20_URA7_URA8_002-crop4_frame_78.tiff
# Image 577, shape: ch20_URA7_URA8_002-crop4_frame_79.tiff
# Image 578, shape: ch20_URA7_URA8_002-crop4_frame_8.tiff
# Image 579, shape: ch20_URA7_URA8_002-crop4_frame_80.tiff
# Image 580, shape: ch20_URA7_URA8_002-crop4_frame_81.tiff
# Image 581, shape: ch20_URA7_URA8_002-crop4_frame_82.tiff
# Image 582, shape: ch20_URA7_URA8_002-crop4_frame_83.tiff
# Image 583, shape: ch20_URA7_URA8_002-crop4_frame_84.tiff
# Image 584, shape: ch20_URA7_URA8_002-crop4_frame_85.tiff
# Image 585, shape: ch20_URA7_URA8_002-crop4_frame_86.tiff
# Image 586, shape: ch20_URA7_URA8_002-crop4_frame_87.tiff
# Image 587, shape: ch20_URA7_URA8_002-crop4_frame_88.tiff
# Image 588, shape: ch20_URA7_URA8_002-crop4_frame_89.tiff
# Image 589, shape: ch20_URA7_URA8_002-crop4_frame_9.tiff
# Image 590, shape: ch20_URA7_URA8_002-crop4_frame_90.tiff
# Image 591, shape: ch20_URA7_URA8_002-crop4_frame_91.tiff
# Image 592, shape: ch20_URA7_URA8_002-crop4_frame_92.tiff
# Image 593, shape: ch20_URA7_URA8_002-crop4_frame_93.tiff
# Image 594, shape: ch20_URA7_URA8_002-crop4_frame_94.tiff
# Image 595, shape: ch20_URA7_URA8_002-crop4_frame_95.tiff
# Image 596, shape: ch20_URA7_URA8_002-crop4_frame_96.tiff
# Image 597, shape: ch20_URA7_URA8_002-crop4_frame_97.tiff
# Image 598, shape: ch20_URA7_URA8_002-crop4_frame_98.tiff
# Image 599, shape: ch20_URA7_URA8_002-crop4_frame_99.tiff
# Image 600, shape: ch20_URA7_URA8_002-crop5_frame_0.tiff
# Image 601, shape: ch20_URA7_URA8_002-crop5_frame_1.tiff
# Image 602, shape: ch20_URA7_URA8_002-crop5_frame_10.tiff
# Image 603, shape: ch20_URA7_URA8_002-crop5_frame_11.tiff
# Image 604, shape: ch20_URA7_URA8_002-crop5_frame_12.tiff
# Image 605, shape: ch20_URA7_URA8_002-crop5_frame_13.tiff
# Image 606, shape: ch20_URA7_URA8_002-crop5_frame_14.tiff
# Image 607, shape: ch20_URA7_URA8_002-crop5_frame_15.tiff
# Image 608, shape: ch20_URA7_URA8_002-crop5_frame_16.tiff
# Image 609, shape: ch20_URA7_URA8_002-crop5_frame_17.tiff
# Image 610, shape: ch20_URA7_URA8_002-crop5_frame_18.tiff
# Image 611, shape: ch20_URA7_URA8_002-crop5_frame_19.tiff
# Image 612, shape: ch20_URA7_URA8_002-crop5_frame_2.tiff
# Image 613, shape: ch20_URA7_URA8_002-crop5_frame_20.tiff
# Image 614, shape: ch20_URA7_URA8_002-crop5_frame_21.tiff
# Image 615, shape: ch20_URA7_URA8_002-crop5_frame_22.tiff
# Image 616, shape: ch20_URA7_URA8_002-crop5_frame_23.tiff
# Image 617, shape: ch20_URA7_URA8_002-crop5_frame_24.tiff
# Image 618, shape: ch20_URA7_URA8_002-crop5_frame_25.tiff
# Image 619, shape: ch20_URA7_URA8_002-crop5_frame_26.tiff
# Image 620, shape: ch20_URA7_URA8_002-crop5_frame_27.tiff
# Image 621, shape: ch20_URA7_URA8_002-crop5_frame_28.tiff
# Image 622, shape: ch20_URA7_URA8_002-crop5_frame_29.tiff
# Image 623, shape: ch20_URA7_URA8_002-crop5_frame_3.tiff
# Image 624, shape: ch20_URA7_URA8_002-crop5_frame_30.tiff
# Image 625, shape: ch20_URA7_URA8_002-crop5_frame_31.tiff
# Image 626, shape: ch20_URA7_URA8_002-crop5_frame_32.tiff
# Image 627, shape: ch20_URA7_URA8_002-crop5_frame_33.tiff
# Image 628, shape: ch20_URA7_URA8_002-crop5_frame_34.tiff
# Image 629, shape: ch20_URA7_URA8_002-crop5_frame_35.tiff
# Image 630, shape: ch20_URA7_URA8_002-crop5_frame_36.tiff
# Image 631, shape: ch20_URA7_URA8_002-crop5_frame_37.tiff
# Image 632, shape: ch20_URA7_URA8_002-crop5_frame_38.tiff
# Image 633, shape: ch20_URA7_URA8_002-crop5_frame_39.tiff
# Image 634, shape: ch20_URA7_URA8_002-crop5_frame_4.tiff
# Image 635, shape: ch20_URA7_URA8_002-crop5_frame_40.tiff
# Image 636, shape: ch20_URA7_URA8_002-crop5_frame_41.tiff
# Image 637, shape: ch20_URA7_URA8_002-crop5_frame_42.tiff
# Image 638, shape: ch20_URA7_URA8_002-crop5_frame_43.tiff
# Image 639, shape: ch20_URA7_URA8_002-crop5_frame_44.tiff
# Image 640, shape: ch20_URA7_URA8_002-crop5_frame_45.tiff
# Image 641, shape: ch20_URA7_URA8_002-crop5_frame_46.tiff
# Image 642, shape: ch20_URA7_URA8_002-crop5_frame_47.tiff
# Image 643, shape: ch20_URA7_URA8_002-crop5_frame_48.tiff
# Image 644, shape: ch20_URA7_URA8_002-crop5_frame_49.tiff
# Image 645, shape: ch20_URA7_URA8_002-crop5_frame_5.tiff
# Image 646, shape: ch20_URA7_URA8_002-crop5_frame_50.tiff
# Image 647, shape: ch20_URA7_URA8_002-crop5_frame_51.tiff
# Image 648, shape: ch20_URA7_URA8_002-crop5_frame_52.tiff
# Image 649, shape: ch20_URA7_URA8_002-crop5_frame_53.tiff
# Image 650, shape: ch20_URA7_URA8_002-crop5_frame_54.tiff
# Image 651, shape: ch20_URA7_URA8_002-crop5_frame_55.tiff
# Image 652, shape: ch20_URA7_URA8_002-crop5_frame_56.tiff
# Image 653, shape: ch20_URA7_URA8_002-crop5_frame_57.tiff
# Image 654, shape: ch20_URA7_URA8_002-crop5_frame_58.tiff
# Image 655, shape: ch20_URA7_URA8_002-crop5_frame_59.tiff
# Image 656, shape: ch20_URA7_URA8_002-crop5_frame_6.tiff
# Image 657, shape: ch20_URA7_URA8_002-crop5_frame_60.tiff
# Image 658, shape: ch20_URA7_URA8_002-crop5_frame_61.tiff
# Image 659, shape: ch20_URA7_URA8_002-crop5_frame_62.tiff
# Image 660, shape: ch20_URA7_URA8_002-crop5_frame_63.tiff
# Image 661, shape: ch20_URA7_URA8_002-crop5_frame_64.tiff
# Image 662, shape: ch20_URA7_URA8_002-crop5_frame_65.tiff
# Image 663, shape: ch20_URA7_URA8_002-crop5_frame_66.tiff
# Image 664, shape: ch20_URA7_URA8_002-crop5_frame_67.tiff
# Image 665, shape: ch20_URA7_URA8_002-crop5_frame_68.tiff
# Image 666, shape: ch20_URA7_URA8_002-crop5_frame_69.tiff
# Image 667, shape: ch20_URA7_URA8_002-crop5_frame_7.tiff
# Image 668, shape: ch20_URA7_URA8_002-crop5_frame_70.tiff
# Image 669, shape: ch20_URA7_URA8_002-crop5_frame_71.tiff
# Image 670, shape: ch20_URA7_URA8_002-crop5_frame_72.tiff
# Image 671, shape: ch20_URA7_URA8_002-crop5_frame_73.tiff
# Image 672, shape: ch20_URA7_URA8_002-crop5_frame_74.tiff
# Image 673, shape: ch20_URA7_URA8_002-crop5_frame_75.tiff
# Image 674, shape: ch20_URA7_URA8_002-crop5_frame_76.tiff
# Image 675, shape: ch20_URA7_URA8_002-crop5_frame_77.tiff
# Image 676, shape: ch20_URA7_URA8_002-crop5_frame_78.tiff
# Image 677, shape: ch20_URA7_URA8_002-crop5_frame_79.tiff
# Image 678, shape: ch20_URA7_URA8_002-crop5_frame_8.tiff
# Image 679, shape: ch20_URA7_URA8_002-crop5_frame_80.tiff
# Image 680, shape: ch20_URA7_URA8_002-crop5_frame_81.tiff
# Image 681, shape: ch20_URA7_URA8_002-crop5_frame_82.tiff
# Image 682, shape: ch20_URA7_URA8_002-crop5_frame_83.tiff
# Image 683, shape: ch20_URA7_URA8_002-crop5_frame_84.tiff
# Image 684, shape: ch20_URA7_URA8_002-crop5_frame_85.tiff
# Image 685, shape: ch20_URA7_URA8_002-crop5_frame_86.tiff
# Image 686, shape: ch20_URA7_URA8_002-crop5_frame_87.tiff
# Image 687, shape: ch20_URA7_URA8_002-crop5_frame_88.tiff
# Image 688, shape: ch20_URA7_URA8_002-crop5_frame_89.tiff
# Image 689, shape: ch20_URA7_URA8_002-crop5_frame_9.tiff
# Image 690, shape: ch20_URA7_URA8_002-crop5_frame_90.tiff
# Image 691, shape: ch20_URA7_URA8_002-crop5_frame_91.tiff
# Image 692, shape: ch20_URA7_URA8_002-crop5_frame_92.tiff
# Image 693, shape: ch20_URA7_URA8_002-crop5_frame_93.tiff
# Image 694, shape: ch20_URA7_URA8_002-crop5_frame_94.tiff
# Image 695, shape: ch20_URA7_URA8_002-crop5_frame_95.tiff
# Image 696, shape: ch20_URA7_URA8_002-crop5_frame_96.tiff
# Image 697, shape: ch20_URA7_URA8_002-crop5_frame_97.tiff
# Image 698, shape: ch20_URA7_URA8_002-crop5_frame_98.tiff
# Image 699, shape: ch20_URA7_URA8_002-crop5_frame_99.tiff
# Image 700, shape: ch20_URA7_URA8_002-crop6_frame_0.tiff
# Image 701, shape: ch20_URA7_URA8_002-crop6_frame_1.tiff
# Image 702, shape: ch20_URA7_URA8_002-crop6_frame_10.tiff
# Image 703, shape: ch20_URA7_URA8_002-crop6_frame_11.tiff
# Image 704, shape: ch20_URA7_URA8_002-crop6_frame_12.tiff
# Image 705, shape: ch20_URA7_URA8_002-crop6_frame_13.tiff
# Image 706, shape: ch20_URA7_URA8_002-crop6_frame_14.tiff
# Image 707, shape: ch20_URA7_URA8_002-crop6_frame_15.tiff
# Image 708, shape: ch20_URA7_URA8_002-crop6_frame_16.tiff
# Image 709, shape: ch20_URA7_URA8_002-crop6_frame_17.tiff
# Image 710, shape: ch20_URA7_URA8_002-crop6_frame_18.tiff
# Image 711, shape: ch20_URA7_URA8_002-crop6_frame_19.tiff
# Image 712, shape: ch20_URA7_URA8_002-crop6_frame_2.tiff
# Image 713, shape: ch20_URA7_URA8_002-crop6_frame_20.tiff
# Image 714, shape: ch20_URA7_URA8_002-crop6_frame_21.tiff
# Image 715, shape: ch20_URA7_URA8_002-crop6_frame_22.tiff
# Image 716, shape: ch20_URA7_URA8_002-crop6_frame_23.tiff
# Image 717, shape: ch20_URA7_URA8_002-crop6_frame_24.tiff
# Image 718, shape: ch20_URA7_URA8_002-crop6_frame_25.tiff
# Image 719, shape: ch20_URA7_URA8_002-crop6_frame_26.tiff
# Image 720, shape: ch20_URA7_URA8_002-crop6_frame_27.tiff
# Image 721, shape: ch20_URA7_URA8_002-crop6_frame_28.tiff
# Image 722, shape: ch20_URA7_URA8_002-crop6_frame_29.tiff
# Image 723, shape: ch20_URA7_URA8_002-crop6_frame_3.tiff
# Image 724, shape: ch20_URA7_URA8_002-crop6_frame_30.tiff
# Image 725, shape: ch20_URA7_URA8_002-crop6_frame_31.tiff
# Image 726, shape: ch20_URA7_URA8_002-crop6_frame_32.tiff
# Image 727, shape: ch20_URA7_URA8_002-crop6_frame_33.tiff
# Image 728, shape: ch20_URA7_URA8_002-crop6_frame_34.tiff
# Image 729, shape: ch20_URA7_URA8_002-crop6_frame_35.tiff
# Image 730, shape: ch20_URA7_URA8_002-crop6_frame_36.tiff
# Image 731, shape: ch20_URA7_URA8_002-crop6_frame_37.tiff
# Image 732, shape: ch20_URA7_URA8_002-crop6_frame_38.tiff
# Image 733, shape: ch20_URA7_URA8_002-crop6_frame_39.tiff
# Image 734, shape: ch20_URA7_URA8_002-crop6_frame_4.tiff
# Image 735, shape: ch20_URA7_URA8_002-crop6_frame_40.tiff
# Image 736, shape: ch20_URA7_URA8_002-crop6_frame_41.tiff
# Image 737, shape: ch20_URA7_URA8_002-crop6_frame_42.tiff
# Image 738, shape: ch20_URA7_URA8_002-crop6_frame_43.tiff
# Image 739, shape: ch20_URA7_URA8_002-crop6_frame_44.tiff
# Image 740, shape: ch20_URA7_URA8_002-crop6_frame_45.tiff
# Image 741, shape: ch20_URA7_URA8_002-crop6_frame_46.tiff
# Image 742, shape: ch20_URA7_URA8_002-crop6_frame_47.tiff
# Image 743, shape: ch20_URA7_URA8_002-crop6_frame_48.tiff
# Image 744, shape: ch20_URA7_URA8_002-crop6_frame_49.tiff
# Image 745, shape: ch20_URA7_URA8_002-crop6_frame_5.tiff
# Image 746, shape: ch20_URA7_URA8_002-crop6_frame_50.tiff
# Image 747, shape: ch20_URA7_URA8_002-crop6_frame_51.tiff
# Image 748, shape: ch20_URA7_URA8_002-crop6_frame_52.tiff
# Image 749, shape: ch20_URA7_URA8_002-crop6_frame_53.tiff
# Image 750, shape: ch20_URA7_URA8_002-crop6_frame_54.tiff
# Image 751, shape: ch20_URA7_URA8_002-crop6_frame_55.tiff
# Image 752, shape: ch20_URA7_URA8_002-crop6_frame_56.tiff
# Image 753, shape: ch20_URA7_URA8_002-crop6_frame_57.tiff
# Image 754, shape: ch20_URA7_URA8_002-crop6_frame_58.tiff
# Image 755, shape: ch20_URA7_URA8_002-crop6_frame_59.tiff
# Image 756, shape: ch20_URA7_URA8_002-crop6_frame_6.tiff
# Image 757, shape: ch20_URA7_URA8_002-crop6_frame_60.tiff
# Image 758, shape: ch20_URA7_URA8_002-crop6_frame_61.tiff
# Image 759, shape: ch20_URA7_URA8_002-crop6_frame_62.tiff
# Image 760, shape: ch20_URA7_URA8_002-crop6_frame_63.tiff
# Image 761, shape: ch20_URA7_URA8_002-crop6_frame_64.tiff
# Image 762, shape: ch20_URA7_URA8_002-crop6_frame_65.tiff
# Image 763, shape: ch20_URA7_URA8_002-crop6_frame_66.tiff
# Image 764, shape: ch20_URA7_URA8_002-crop6_frame_67.tiff
# Image 765, shape: ch20_URA7_URA8_002-crop6_frame_68.tiff
# Image 766, shape: ch20_URA7_URA8_002-crop6_frame_69.tiff
# Image 767, shape: ch20_URA7_URA8_002-crop6_frame_7.tiff
# Image 768, shape: ch20_URA7_URA8_002-crop6_frame_70.tiff
# Image 769, shape: ch20_URA7_URA8_002-crop6_frame_71.tiff
# Image 770, shape: ch20_URA7_URA8_002-crop6_frame_72.tiff
# Image 771, shape: ch20_URA7_URA8_002-crop6_frame_73.tiff
# Image 772, shape: ch20_URA7_URA8_002-crop6_frame_74.tiff
# Image 773, shape: ch20_URA7_URA8_002-crop6_frame_75.tiff
# Image 774, shape: ch20_URA7_URA8_002-crop6_frame_76.tiff
# Image 775, shape: ch20_URA7_URA8_002-crop6_frame_77.tiff
# Image 776, shape: ch20_URA7_URA8_002-crop6_frame_78.tiff
# Image 777, shape: ch20_URA7_URA8_002-crop6_frame_79.tiff
# Image 778, shape: ch20_URA7_URA8_002-crop6_frame_8.tiff
# Image 779, shape: ch20_URA7_URA8_002-crop6_frame_80.tiff
# Image 780, shape: ch20_URA7_URA8_002-crop6_frame_81.tiff
# Image 781, shape: ch20_URA7_URA8_002-crop6_frame_82.tiff
# Image 782, shape: ch20_URA7_URA8_002-crop6_frame_83.tiff
# Image 783, shape: ch20_URA7_URA8_002-crop6_frame_84.tiff
# Image 784, shape: ch20_URA7_URA8_002-crop6_frame_85.tiff
# Image 785, shape: ch20_URA7_URA8_002-crop6_frame_86.tiff
# Image 786, shape: ch20_URA7_URA8_002-crop6_frame_87.tiff
# Image 787, shape: ch20_URA7_URA8_002-crop6_frame_88.tiff
# Image 788, shape: ch20_URA7_URA8_002-crop6_frame_89.tiff
# Image 789, shape: ch20_URA7_URA8_002-crop6_frame_9.tiff
# Image 790, shape: ch20_URA7_URA8_002-crop6_frame_90.tiff
# Image 791, shape: ch20_URA7_URA8_002-crop6_frame_91.tiff
# Image 792, shape: ch20_URA7_URA8_002-crop6_frame_92.tiff
# Image 793, shape: ch20_URA7_URA8_002-crop6_frame_93.tiff
# Image 794, shape: ch20_URA7_URA8_002-crop6_frame_94.tiff
# Image 795, shape: ch20_URA7_URA8_002-crop6_frame_95.tiff
# Image 796, shape: ch20_URA7_URA8_002-crop6_frame_96.tiff
# Image 797, shape: ch20_URA7_URA8_002-crop6_frame_97.tiff
# Image 798, shape: ch20_URA7_URA8_002-crop6_frame_98.tiff
# Image 799, shape: ch20_URA7_URA8_002-crop6_frame_99.tiff

# %%
n = 6
_=matrix_to_image(filtered_imgs[n].original_image)
_=matrix_to_image(filtered_imgs[n].blacked_image)
# Out:
# <PIL.Image.Image image mode=L size=128x128>
# <PIL.Image.Image image mode=L size=128x128>

# %%
import numpy as np
from sklearn.cluster import DBSCAN

# cleaned: your cleaned 2D numpy image (uint8/float), e.g. after blacking low pixels
# Example: cleaned = img_clean
cleaned = filtered_imgs[n].blacked_image

# 1) Keep only non-black pixels
mask = cleaned > 0
rows, cols = np.where(mask)

# 2) Build DBSCAN features
# spatial coords
x = cols.astype(np.float32)
y = rows.astype(np.float32)

# optional: include intensity as 3rd feature
intensity = cleaned[rows, cols].astype(np.float32)
intensity = intensity / 255.0   # keep scale comparable
intensity_weight = 0.3          # tune this
intensity = intensity * intensity_weight

X = np.column_stack([x, y, intensity])   # or np.column_stack([x, y]) for spatial only

# 3) Run DBSCAN
db = DBSCAN(eps=2.0, min_samples=5)      # tune eps/min_samples
labels = db.fit_predict(X)

# 4) Put labels back into image shape for plotting
cluster_map = np.full(cleaned.shape, -1, dtype=np.int32)
cluster_map[rows, cols] = labels

n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
n_noise = np.sum(labels == -1)
print(f"clusters={n_clusters}, noise={n_noise}")
# Out:
# clusters=1, noise=15

# %%
import matplotlib.pyplot as plt

# Build an RGB image for cluster visualization
# noise (-1) stays black; each cluster id gets a random color
cluster_rgb = np.zeros((*cluster_map.shape, 3), dtype=np.uint8)

valid = labels >= 0
unique_labels = np.unique(labels[valid])
rng = np.random.default_rng(42)
colors = rng.integers(40, 255, size=(len(unique_labels), 3), dtype=np.uint8)

for idx, label in enumerate(unique_labels):
    pix = labels == label
    cluster_rgb[rows[pix], cols[pix]] = colors[idx]

plt.figure(figsize=(5, 5))
plt.imshow(cluster_rgb)
plt.title(f"DBSCAN clusters: {n_clusters} (noise: {n_noise})")
plt.axis("off")
plt.show()

# %%
from tqdm.auto import tqdm

eps_search_space = [0.5,1,2,5]
min_samples_search_space = [5,10,20,30]

for eps in tqdm(eps_search_space):
    for min_samples in tqdm(min_samples_search_space):
        for i in tqdm(range(len(filtered_imgs)), leave=False):
            n = i
            # _=matrix_to_image(filtered_imgs[n].original_image)
            # _=matrix_to_image(filtered_imgs[n].blacked_image)

            import numpy as np
            from sklearn.cluster import DBSCAN

            # cleaned: your cleaned 2D numpy image (uint8/float), e.g. after blacking low pixels
            # Example: cleaned = img_clean
            cleaned = filtered_imgs[n].blacked_image

            # 1) Keep only non-black pixels
            mask = cleaned > 0
            rows, cols = np.where(mask)

            # 2) Build DBSCAN features
            # spatial coords
            x = cols.astype(np.float32)
            y = rows.astype(np.float32)

            # optional: include intensity as 3rd feature
            intensity = cleaned[rows, cols].astype(np.float32)
            intensity = intensity / 255.0   # keep scale comparable
            intensity_weight = 0.3          # tune this
            intensity = intensity * intensity_weight

            X = np.column_stack([x, y, intensity])   # or np.column_stack([x, y]) for spatial only

            # 3) Run DBSCAN
            db = DBSCAN(eps=2.0, min_samples=5)      # tune eps/min_samples
            labels = db.fit_predict(X)

            # 4) Put labels back into image shape for plotting
            cluster_map = np.full(cleaned.shape, -1, dtype=np.int32)
            cluster_map[rows, cols] = labels

            n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
            n_noise = np.sum(labels == -1)
            # print(f"clusters={n_clusters}, noise={n_noise}")


            import matplotlib.pyplot as plt

            # Build an RGB image for cluster visualization
            # noise (-1) stays black; each cluster id gets a random color
            cluster_rgb = np.zeros((*cluster_map.shape, 3), dtype=np.uint8)

            valid = labels >= 0
            unique_labels = np.unique(labels[valid])
            rng = np.random.default_rng(42)
            colors = rng.integers(40, 255, size=(len(unique_labels), 3), dtype=np.uint8)

            for idx, label in enumerate(unique_labels):
                pix = labels == label
                cluster_rgb[rows[pix], cols[pix]] = colors[idx]

            # plt.figure(figsize=(5, 5))
            # plt.imshow(cluster_rgb)
            # plt.title(f"DBSCAN clusters: {n_clusters} (noise: {n_noise})")
            # plt.axis("off")
            # plt.show()

            # Plot original, blackened, and clustered image side-by-side and save
            output_dir = Path(rf"outputs/dbscan_eps{eps}_min_samples{min_samples}")  # change to your specific folder
            output_dir.mkdir(parents=True, exist_ok=True)

            sample = filtered_imgs[n]

            fig, axes = plt.subplots(1, 3, figsize=(12, 4))

            axes[0].imshow(sample.original_image, cmap="gray")
            axes[0].set_title("Original")
            axes[0].axis("off")

            axes[1].imshow(sample.blacked_image, cmap="gray")
            axes[1].set_title("Blackened")
            axes[1].axis("off")

            axes[2].imshow(cluster_rgb)
            axes[2].set_title(f"Clustered ({n_clusters} clusters)")
            axes[2].axis("off")

            fig.suptitle(sample.path.name)
            fig.tight_layout()

            save_path = output_dir / f"{sample.path.stem}_overview.png"
            _ = fig.savefig(save_path, dpi=200, bbox_inches="tight")
            plt.close(fig)
            # plt.show()

            # print(f"Saved: {save_path}")
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/800 [00:00<?, ?it/s]
# clusters=1, noise=17
# clusters=1, noise=15
# clusters=2, noise=18
# clusters=3, noise=12
# clusters=2, noise=12
# clusters=1, noise=7
# clusters=1, noise=15
# clusters=1, noise=5
# clusters=2, noise=15
# clusters=1, noise=19
# clusters=3, noise=18
# clusters=2, noise=13
# clusters=3, noise=20
# clusters=1, noise=24
# clusters=1, noise=30
# clusters=1, noise=29
# clusters=1, noise=40
# clusters=1, noise=42
# clusters=3, noise=42
# clusters=3, noise=30
# clusters=2, noise=48
# clusters=2, noise=54
# clusters=1, noise=53
# clusters=2, noise=42
# clusters=1, noise=57
# clusters=4, noise=52
# clusters=1, noise=61
# clusters=3, noise=43
# clusters=2, noise=50
# clusters=2, noise=59
# clusters=1, noise=62
# clusters=2, noise=57
# clusters=2, noise=61
# clusters=1, noise=66
# clusters=2, noise=10
# clusters=3, noise=55
# clusters=4, noise=58
# clusters=3, noise=52
# clusters=2, noise=59
# clusters=2, noise=54
# clusters=4, noise=44
# clusters=1, noise=72
# clusters=2, noise=44
# clusters=1, noise=57
# clusters=2, noise=51
# clusters=1, noise=17
# clusters=3, noise=58
# clusters=2, noise=65
# clusters=2, noise=52
# clusters=1, noise=72
# clusters=2, noise=51
# clusters=4, noise=45
# clusters=2, noise=66
# clusters=5, noise=40
# clusters=5, noise=34
# clusters=3, noise=54
# clusters=2, noise=16
# clusters=4, noise=42
# clusters=2, noise=72
# clusters=5, noise=45
# clusters=2, noise=64
# clusters=0, noise=69
# clusters=2, noise=65
# clusters=3, noise=55
# clusters=3, noise=44
# clusters=5, noise=48
# clusters=4, noise=54
# clusters=2, noise=18
# clusters=3, noise=51
# clusters=4, noise=55
# clusters=2, noise=56
# clusters=3, noise=46
# clusters=1, noise=58
# clusters=2, noise=59
# clusters=4, noise=46
# clusters=2, noise=67
# clusters=3, noise=51
# clusters=2, noise=65
# clusters=2, noise=9
# clusters=4, noise=46
# clusters=4, noise=43
# clusters=2, noise=63
# clusters=2, noise=52
# clusters=4, noise=44
# clusters=2, noise=54
# clusters=1, noise=72
# clusters=2, noise=49
# clusters=1, noise=55
# clusters=1, noise=68
# clusters=2, noise=18
# clusters=0, noise=71
# clusters=4, noise=52
# clusters=0, noise=67
# clusters=3, noise=61
# clusters=1, noise=62
# clusters=2, noise=61
# clusters=1, noise=68
# clusters=2, noise=67
# clusters=2, noise=62
# clusters=3, noise=47
# clusters=1, noise=26
# clusters=4, noise=47
# clusters=4, noise=23
# clusters=3, noise=24
# clusters=6, noise=22
# clusters=3, noise=14
# clusters=2, noise=18
# clusters=4, noise=16
# clusters=2, noise=22
# clusters=3, noise=17
# clusters=3, noise=26
# clusters=1, noise=14
# clusters=3, noise=54
# clusters=1, noise=12
# clusters=1, noise=9
# clusters=1, noise=12
# clusters=1, noise=10
# clusters=1, noise=12
# clusters=1, noise=15
# clusters=2, noise=7
# clusters=2, noise=19
# clusters=2, noise=15
# clusters=2, noise=15
# clusters=2, noise=21
# clusters=1, noise=22
# clusters=1, noise=16
# clusters=1, noise=14
# clusters=1, noise=9
# clusters=2, noise=12
# clusters=1, noise=10
# clusters=1, noise=12
# clusters=1, noise=12
# clusters=2, noise=15
# clusters=1, noise=15
# clusters=1, noise=34
# clusters=1, noise=22
# clusters=1, noise=11
# clusters=1, noise=29
# clusters=2, noise=31
# clusters=2, noise=26
# clusters=1, noise=34
# clusters=6, noise=33
# clusters=3, noise=33
# clusters=1, noise=30
# clusters=4, noise=33
# clusters=2, noise=34
# clusters=4, noise=28
# clusters=3, noise=35
# clusters=3, noise=27
# clusters=2, noise=38
# clusters=4, noise=22
# clusters=3, noise=34
# clusters=2, noise=42
# clusters=2, noise=54
# clusters=3, noise=46
# clusters=4, noise=36
# clusters=4, noise=28
# clusters=2, noise=58
# clusters=3, noise=47
# clusters=3, noise=57
# clusters=1, noise=27
# clusters=5, noise=37
# clusters=3, noise=44
# clusters=4, noise=19
# clusters=2, noise=59
# clusters=2, noise=51
# clusters=1, noise=62
# clusters=3, noise=36
# clusters=3, noise=49
# clusters=2, noise=54
# clusters=1, noise=64
# clusters=3, noise=49
# clusters=3, noise=53
# clusters=3, noise=52
# clusters=5, noise=40
# clusters=1, noise=57
# clusters=2, noise=60
# clusters=1, noise=63
# clusters=1, noise=27
# clusters=2, noise=52
# clusters=1, noise=60
# clusters=2, noise=63
# clusters=3, noise=52
# clusters=3, noise=53
# clusters=2, noise=55
# clusters=1, noise=52
# clusters=1, noise=60
# clusters=1, noise=72
# clusters=1, noise=43
# clusters=2, noise=33
# clusters=2, noise=55
# clusters=2, noise=58
# clusters=2, noise=51
# clusters=2, noise=65
# clusters=1, noise=48
# clusters=0, noise=65
# clusters=0, noise=61
# clusters=1, noise=65
# clusters=0, noise=73
# clusters=3, noise=60
# clusters=1, noise=27
# clusters=1, noise=29
# clusters=2, noise=13
# clusters=1, noise=18
# clusters=2, noise=16
# clusters=1, noise=38
# clusters=2, noise=34
# clusters=2, noise=53
# clusters=1, noise=44
# clusters=2, noise=48
# clusters=3, noise=22
# clusters=2, noise=34
# clusters=2, noise=30
# clusters=2, noise=51
# clusters=2, noise=57
# clusters=1, noise=59
# clusters=1, noise=48
# clusters=4, noise=55
# clusters=3, noise=41
# clusters=4, noise=21
# clusters=2, noise=18
# clusters=2, noise=20
# clusters=3, noise=16
# clusters=1, noise=72
# clusters=3, noise=17
# clusters=1, noise=18
# clusters=1, noise=25
# clusters=1, noise=13
# clusters=1, noise=24
# clusters=1, noise=13
# clusters=1, noise=18
# clusters=3, noise=25
# clusters=1, noise=35
# clusters=2, noise=30
# clusters=2, noise=52
# clusters=4, noise=28
# clusters=2, noise=21
# clusters=1, noise=35
# clusters=1, noise=16
# clusters=1, noise=11
# clusters=1, noise=19
# clusters=1, noise=15
# clusters=2, noise=12
# clusters=1, noise=15
# clusters=1, noise=21
# clusters=2, noise=34
# clusters=1, noise=27
# clusters=1, noise=18
# clusters=2, noise=14
# clusters=1, noise=26
# clusters=2, noise=29
# clusters=1, noise=21
# clusters=1, noise=22
# clusters=3, noise=22
# clusters=2, noise=32
# clusters=5, noise=44
# clusters=2, noise=35
# clusters=3, noise=31
# clusters=4, noise=46
# clusters=1, noise=21
# clusters=3, noise=22
# clusters=1, noise=37
# clusters=1, noise=27
# clusters=2, noise=21
# clusters=3, noise=37
# clusters=3, noise=27
# clusters=3, noise=32
# clusters=1, noise=32
# clusters=5, noise=33
# clusters=4, noise=34
# clusters=5, noise=43
# clusters=2, noise=59
# clusters=2, noise=44
# clusters=1, noise=42
# clusters=3, noise=56
# clusters=2, noise=57
# clusters=2, noise=64
# clusters=0, noise=63
# clusters=1, noise=23
# clusters=2, noise=55
# clusters=1, noise=54
# clusters=3, noise=49
# clusters=1, noise=65
# clusters=1, noise=54
# clusters=1, noise=50
# clusters=1, noise=72
# clusters=2, noise=51
# clusters=2, noise=63
# clusters=1, noise=66
# clusters=1, noise=17
# clusters=3, noise=50
# clusters=0, noise=58
# clusters=1, noise=62
# clusters=1, noise=54
# clusters=2, noise=58
# clusters=0, noise=71
# clusters=0, noise=64
# clusters=0, noise=74
# clusters=2, noise=61
# clusters=1, noise=54
# clusters=1, noise=74
# clusters=2, noise=46
# clusters=2, noise=35
# clusters=2, noise=25
# clusters=1, noise=48
# clusters=2, noise=51
# clusters=2, noise=55
# clusters=1, noise=64
# clusters=3, noise=49
# clusters=2, noise=52
# clusters=2, noise=55
# clusters=1, noise=56
# clusters=1, noise=75
# clusters=4, noise=34
# clusters=3, noise=48
# clusters=2, noise=40
# clusters=3, noise=54
# clusters=4, noise=50
# clusters=1, noise=73
# clusters=1, noise=63
# clusters=3, noise=48
# clusters=4, noise=43
# clusters=3, noise=56
# clusters=1, noise=57
# clusters=0, noise=72
# clusters=0, noise=69
# clusters=2, noise=54
# clusters=5, noise=53
# clusters=0, noise=60
# clusters=3, noise=52
# clusters=6, noise=46
# clusters=3, noise=51
# clusters=2, noise=66
# clusters=3, noise=43
# clusters=1, noise=49
# clusters=1, noise=66
# clusters=3, noise=62
# clusters=1, noise=70
# clusters=3, noise=55
# clusters=1, noise=55
# clusters=3, noise=61
# clusters=3, noise=50
# clusters=2, noise=62
# clusters=2, noise=52
# clusters=2, noise=58
# clusters=3, noise=20
# clusters=2, noise=72
# clusters=3, noise=65
# clusters=1, noise=64
# clusters=2, noise=68
# clusters=1, noise=74
# clusters=2, noise=46
# clusters=2, noise=57
# clusters=3, noise=52
# clusters=3, noise=58
# clusters=0, noise=66
# clusters=1, noise=23
# clusters=0, noise=76
# clusters=1, noise=67
# clusters=1, noise=56
# clusters=3, noise=46
# clusters=2, noise=68
# clusters=2, noise=50
# clusters=1, noise=64
# clusters=3, noise=33
# clusters=4, noise=34
# clusters=3, noise=34
# clusters=1, noise=21
# clusters=5, noise=38
# clusters=3, noise=28
# clusters=4, noise=39
# clusters=4, noise=25
# clusters=5, noise=30
# clusters=5, noise=34
# clusters=5, noise=31
# clusters=6, noise=25
# clusters=3, noise=54
# clusters=4, noise=35
# clusters=2, noise=30
# clusters=4, noise=32
# clusters=4, noise=44
# clusters=5, noise=40
# clusters=3, noise=34
# clusters=4, noise=45
# clusters=2, noise=40
# clusters=3, noise=45
# clusters=2, noise=31
# clusters=5, noise=34
# clusters=1, noise=47
# clusters=2, noise=34
# clusters=3, noise=38
# clusters=5, noise=39
# clusters=4, noise=38
# clusters=1, noise=36
# clusters=6, noise=39
# clusters=3, noise=31
# clusters=2, noise=40
# clusters=3, noise=18
# clusters=3, noise=20
# clusters=4, noise=17
# clusters=1, noise=9
# clusters=1, noise=8
# clusters=1, noise=9
# clusters=1, noise=8
# clusters=1, noise=4
# clusters=1, noise=9
# clusters=1, noise=33
# clusters=1, noise=28
# clusters=1, noise=25
# clusters=2, noise=17
# clusters=2, noise=17
# clusters=3, noise=25
# clusters=3, noise=28
# clusters=3, noise=31
# clusters=2, noise=20
# clusters=4, noise=27
# clusters=3, noise=26
# clusters=3, noise=37
# clusters=1, noise=21
# clusters=2, noise=20
# clusters=2, noise=29
# clusters=1, noise=31
# clusters=4, noise=28
# clusters=3, noise=36
# clusters=2, noise=30
# clusters=2, noise=17
# clusters=1, noise=24
# clusters=3, noise=33
# clusters=2, noise=30
# clusters=1, noise=34
# clusters=1, noise=22
# clusters=3, noise=36
# clusters=3, noise=33
# clusters=3, noise=36
# clusters=1, noise=11
# clusters=1, noise=33
# clusters=1, noise=22
# clusters=2, noise=24
# clusters=4, noise=31
# clusters=2, noise=33
# clusters=1, noise=31
# clusters=4, noise=24
# clusters=3, noise=17
# clusters=1, noise=31
# clusters=1, noise=21
# clusters=1, noise=8
# clusters=2, noise=28
# clusters=2, noise=34
# clusters=4, noise=31
# clusters=2, noise=29
# clusters=2, noise=20
# clusters=2, noise=34
# clusters=3, noise=26
# clusters=4, noise=22
# clusters=1, noise=19
# clusters=4, noise=29
# clusters=1, noise=12
# clusters=1, noise=20
# clusters=4, noise=39
# clusters=3, noise=25
# clusters=2, noise=27
# clusters=1, noise=44
# clusters=2, noise=28
# clusters=4, noise=22
# clusters=2, noise=28
# clusters=1, noise=37
# clusters=2, noise=38
# clusters=2, noise=12
# clusters=4, noise=39
# clusters=4, noise=31
# clusters=5, noise=27
# clusters=4, noise=39
# clusters=3, noise=35
# clusters=3, noise=36
# clusters=4, noise=32
# clusters=3, noise=38
# clusters=1, noise=48
# clusters=2, noise=33
# clusters=1, noise=3
# clusters=3, noise=40
# clusters=2, noise=42
# clusters=3, noise=41
# clusters=3, noise=48
# clusters=4, noise=41
# clusters=4, noise=40
# clusters=5, noise=33
# clusters=1, noise=23
# clusters=4, noise=33
# clusters=3, noise=49
# clusters=1, noise=15
# clusters=2, noise=46
# clusters=3, noise=32
# clusters=4, noise=57
# clusters=3, noise=55
# clusters=3, noise=41
# clusters=1, noise=35
# clusters=2, noise=41
# clusters=2, noise=40
# clusters=2, noise=47
# clusters=2, noise=30
# clusters=1, noise=74
# clusters=2, noise=46
# clusters=2, noise=35
# clusters=2, noise=25
# clusters=1, noise=48
# clusters=2, noise=51
# clusters=2, noise=55
# clusters=1, noise=64
# clusters=3, noise=49
# clusters=2, noise=52
# clusters=2, noise=55
# clusters=1, noise=56
# clusters=1, noise=75
# clusters=4, noise=34
# clusters=3, noise=48
# clusters=2, noise=40
# clusters=3, noise=54
# clusters=4, noise=50
# clusters=1, noise=73
# clusters=1, noise=63
# clusters=3, noise=48
# clusters=4, noise=43
# clusters=3, noise=56
# clusters=1, noise=57
# clusters=0, noise=72
# clusters=0, noise=69
# clusters=2, noise=54
# clusters=5, noise=53
# clusters=0, noise=60
# clusters=3, noise=52
# clusters=6, noise=46
# clusters=3, noise=51
# clusters=2, noise=66
# clusters=3, noise=43
# clusters=1, noise=49
# clusters=1, noise=66
# clusters=3, noise=62
# clusters=1, noise=70
# clusters=3, noise=55
# clusters=1, noise=55
# clusters=3, noise=61
# clusters=3, noise=50
# clusters=2, noise=62
# clusters=2, noise=52
# clusters=2, noise=58
# clusters=3, noise=20
# clusters=2, noise=72
# clusters=3, noise=65
# clusters=1, noise=64
# clusters=2, noise=68
# clusters=1, noise=74
# clusters=2, noise=46
# clusters=2, noise=57
# clusters=3, noise=52
# clusters=3, noise=58
# clusters=0, noise=66
# clusters=1, noise=23
# clusters=0, noise=76
# clusters=1, noise=67
# clusters=1, noise=56
# clusters=3, noise=46
# clusters=2, noise=68
# clusters=2, noise=50
# clusters=1, noise=64
# clusters=3, noise=33
# clusters=4, noise=34
# clusters=3, noise=34
# clusters=1, noise=21
# clusters=5, noise=38
# clusters=3, noise=28
# clusters=4, noise=39
# clusters=4, noise=25
# clusters=5, noise=30
# clusters=5, noise=34
# clusters=5, noise=31
# clusters=6, noise=25
# clusters=3, noise=54
# clusters=4, noise=35
# clusters=2, noise=30
# clusters=4, noise=32
# clusters=4, noise=44
# clusters=5, noise=40
# clusters=3, noise=34
# clusters=4, noise=45
# clusters=2, noise=40
# clusters=3, noise=45
# clusters=2, noise=31
# clusters=5, noise=34
# clusters=1, noise=47
# clusters=2, noise=34
# clusters=3, noise=38
# clusters=5, noise=39
# clusters=4, noise=38
# clusters=1, noise=36
# clusters=6, noise=39
# clusters=3, noise=31
# clusters=2, noise=40
# clusters=3, noise=18
# clusters=3, noise=20
# clusters=4, noise=17
# clusters=3, noise=9
# clusters=3, noise=22
# clusters=1, noise=51
# clusters=2, noise=57
# clusters=2, noise=51
# clusters=3, noise=63
# clusters=3, noise=46
# clusters=2, noise=55
# clusters=1, noise=73
# clusters=2, noise=48
# clusters=1, noise=51
# clusters=4, noise=32
# clusters=1, noise=53
# clusters=2, noise=38
# clusters=1, noise=42
# clusters=1, noise=30
# clusters=1, noise=33
# clusters=1, noise=29
# clusters=2, noise=27
# clusters=2, noise=27
# clusters=2, noise=23
# clusters=4, noise=18
# clusters=3, noise=29
# clusters=1, noise=43
# clusters=2, noise=23
# clusters=3, noise=24
# clusters=2, noise=29
# clusters=3, noise=13
# clusters=3, noise=19
# clusters=3, noise=11
# clusters=3, noise=13
# clusters=3, noise=29
# clusters=3, noise=19
# clusters=2, noise=22
# clusters=1, noise=48
# clusters=3, noise=15
# clusters=2, noise=20
# clusters=2, noise=19
# clusters=4, noise=10
# clusters=2, noise=27
# clusters=2, noise=21
# clusters=3, noise=21
# clusters=3, noise=19
# clusters=3, noise=24
# clusters=2, noise=19
# clusters=3, noise=31
# clusters=2, noise=25
# clusters=1, noise=22
# clusters=1, noise=13
# clusters=1, noise=20
# clusters=1, noise=25
# clusters=2, noise=30
# clusters=2, noise=14
# clusters=2, noise=40
# clusters=2, noise=31
# clusters=2, noise=25
# clusters=3, noise=43
# clusters=1, noise=36
# clusters=2, noise=27
# clusters=3, noise=17
# clusters=2, noise=25
# clusters=2, noise=21
# clusters=2, noise=27
# clusters=1, noise=27
# clusters=2, noise=35
# clusters=2, noise=37
# clusters=2, noise=27
# clusters=1, noise=56
# clusters=3, noise=19
# clusters=2, noise=28
# clusters=2, noise=19
# clusters=2, noise=14
# clusters=2, noise=25
# clusters=2, noise=22
# clusters=3, noise=29
# clusters=2, noise=31
# clusters=2, noise=23
# clusters=2, noise=30
# clusters=2, noise=52
# clusters=2, noise=22
# clusters=2, noise=29
# clusters=2, noise=19
# clusters=2, noise=21
# clusters=2, noise=20
# clusters=2, noise=22
# clusters=2, noise=26
# clusters=3, noise=15
# clusters=2, noise=20
# clusters=2, noise=24
# clusters=1, noise=46
# clusters=2, noise=24
# clusters=3, noise=19
# clusters=2, noise=22
# clusters=3, noise=21
# clusters=2, noise=15
# clusters=2, noise=23
# clusters=2, noise=22
# clusters=3, noise=15
# clusters=3, noise=9
# clusters=2, noise=24
# clusters=2, noise=58
# clusters=3, noise=55
# clusters=2, noise=60
# clusters=2, noise=53
# clusters=2, noise=61
# clusters=2, noise=58
# clusters=2, noise=57
# clusters=2, noise=71
# clusters=3, noise=54
# clusters=0, noise=79
# clusters=2, noise=65
# clusters=2, noise=59
# clusters=2, noise=49
# clusters=1, noise=71
# clusters=3, noise=61
# clusters=2, noise=49
# clusters=3, noise=60
# clusters=2, noise=63
# clusters=1, noise=73
# clusters=1, noise=65
# clusters=0, noise=69
# clusters=2, noise=63
# clusters=4, noise=46
# clusters=4, noise=52
# clusters=2, noise=58
# clusters=1, noise=66
# clusters=2, noise=62
# clusters=2, noise=69
# clusters=1, noise=70
# clusters=1, noise=65
# clusters=2, noise=47
# clusters=3, noise=55
# clusters=2, noise=58
# clusters=2, noise=70
# clusters=4, noise=46
# clusters=2, noise=42
# clusters=2, noise=27
# clusters=2, noise=28
# clusters=2, noise=22
# clusters=2, noise=21
# clusters=3, noise=18
# clusters=2, noise=23
# clusters=2, noise=23
# clusters=2, noise=25
# clusters=1, noise=22
# clusters=4, noise=51
# clusters=1, noise=33
# clusters=2, noise=26
# clusters=1, noise=28
# clusters=1, noise=31
# clusters=1, noise=37
# clusters=1, noise=29
# clusters=1, noise=30
# clusters=2, noise=27
# clusters=2, noise=20
# clusters=2, noise=26
# clusters=4, noise=50
# clusters=2, noise=18
# clusters=3, noise=14
# clusters=2, noise=29
# clusters=2, noise=24
# clusters=2, noise=25
# clusters=3, noise=20
# clusters=2, noise=28
# clusters=3, noise=20
# clusters=2, noise=33
# clusters=3, noise=22
# clusters=4, noise=42
# clusters=2, noise=18
# clusters=3, noise=17
# clusters=2, noise=16
# clusters=2, noise=19
# clusters=2, noise=22
# clusters=2, noise=20
# clusters=2, noise=22
# clusters=2, noise=24
# clusters=3, noise=29
# clusters=2, noise=21
# clusters=2, noise=52
# clusters=2, noise=22
# clusters=2, noise=21
# clusters=2, noise=17
# clusters=2, noise=27
# clusters=2, noise=15
# clusters=3, noise=16
# clusters=3, noise=24
# clusters=2, noise=30
# clusters=2, noise=23
# clusters=2, noise=19
# clusters=4, noise=52
# clusters=2, noise=28
# clusters=2, noise=16
# clusters=3, noise=16
# clusters=3, noise=24
# clusters=2, noise=21
# clusters=3, noise=22
# clusters=2, noise=35
# clusters=1, noise=40
# clusters=3, noise=22
# clusters=3, noise=23
#   0%|          | 0/800 [00:00<?, ?it/s]
# clusters=1, noise=17
# clusters=1, noise=15
# clusters=2, noise=18
# clusters=3, noise=12
# clusters=2, noise=12
# clusters=1, noise=7
# clusters=1, noise=15
# clusters=1, noise=5
# clusters=2, noise=15
# clusters=1, noise=19
# clusters=3, noise=18
# clusters=2, noise=13
# clusters=3, noise=20
# clusters=1, noise=24
# clusters=1, noise=30
# clusters=1, noise=29
# clusters=1, noise=40
# clusters=1, noise=42
# clusters=3, noise=42
# clusters=3, noise=30
# clusters=2, noise=48
# clusters=2, noise=54
# clusters=1, noise=53
# clusters=2, noise=42
# clusters=1, noise=57
# clusters=4, noise=52
# clusters=1, noise=61
# clusters=3, noise=43
# clusters=2, noise=50
# clusters=2, noise=59
# clusters=1, noise=62
# clusters=2, noise=57
# clusters=2, noise=61
# clusters=1, noise=66
# clusters=2, noise=10
# clusters=3, noise=55
# clusters=4, noise=58
# clusters=3, noise=52
# clusters=2, noise=59
# clusters=2, noise=54
# clusters=4, noise=44
# clusters=1, noise=72
# clusters=2, noise=44
# clusters=1, noise=57
# clusters=2, noise=51
# clusters=1, noise=17
# clusters=3, noise=58
# clusters=2, noise=65
# clusters=2, noise=52
# clusters=1, noise=72
# clusters=2, noise=51
# clusters=4, noise=45
# clusters=2, noise=66
# clusters=5, noise=40
# clusters=5, noise=34
# clusters=3, noise=54
# clusters=2, noise=16
# clusters=4, noise=42
# clusters=2, noise=72
# clusters=5, noise=45
# clusters=2, noise=64
# clusters=0, noise=69
# clusters=2, noise=65
# clusters=3, noise=55
# clusters=3, noise=44
# clusters=5, noise=48
# clusters=4, noise=54
# clusters=2, noise=18
# clusters=3, noise=51
# clusters=4, noise=55
# clusters=2, noise=56
# clusters=3, noise=46
# clusters=1, noise=58
# clusters=2, noise=59
# clusters=4, noise=46
# clusters=2, noise=67
# clusters=3, noise=51
# clusters=2, noise=65
# clusters=2, noise=9
# clusters=4, noise=46
# clusters=4, noise=43
# clusters=2, noise=63
# clusters=2, noise=52
# clusters=4, noise=44
# clusters=2, noise=54
# clusters=1, noise=72
# clusters=2, noise=49
# clusters=1, noise=55
# clusters=1, noise=68
# clusters=2, noise=18
# clusters=0, noise=71
# clusters=4, noise=52
# clusters=0, noise=67
# clusters=3, noise=61
# clusters=1, noise=62
